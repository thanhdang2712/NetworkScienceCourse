# %% [markdown]
# # ACTIVE LEARNING EXERCISE 7
# ## Networks: Friends, Terrorists, and Epidemics
# ## Due by 11:55pm on Friday, November 18, 2022
#
# ### Name:
# ### Group Member(s):
#
# ## GUIDELINES
# - You may either type or write out your responses. You should provide your own solutions for the questions. For the assignment you can use resources available to you (e.g., textbook, notes, your classmates, tutor, and Prof. Ay.)
# - To receive full credit, you must show all of your work and adhere to the formatting guidelines outlined here. Please keep in mind that some of the questions may be graded based on their completion.
# - Please write your name on your assignment. Submit the answers to questions electronically in one or more documents by uploading a PDF or set of images to Gradescope. If you submit a pdf file, please select each question and then click on the page(s) for that question. Instructions for submitting your work can be found in the posted video (https://www.youtube.com/watch?v=u-pK4GzpId0).
# - You are welcome to use Python and/or Gephi to perform calculations or check your work. Just be sure to include any equations and Python code (or Gephi screenshots) that you used.
# - You can use https://colab.research.google.com/ website to work on this notebook. After finishing your work you can download the notebook.
# - You can use a resource such as https://www.vertopal.com/en/convert/ipynb-to-pdf to convert your Python notebook to a pdf file.
# - You can use a resource such as https://combinepdf.com/ website to combine pdf files. For example if you want to combine your handwritten solutions with your answers that you created through a computer.
# - For the non-coding questions in this assignment, you may enter your responses beneath the question, or write your answers in a Word document and convert it to a pdf file, or write your answers by hand on a piece of paper, photograph it, and convert it to a pdf file.

# %% [markdown]
# ##Q1. (8 pts)
#
# A. Please read ***Joining the dots: How gene regulatory network tools are unearthing drugs*** article and answer the following questions. (***Approximate Total Length: One Page***)
#
# Link: https://www.pharmaceutical-technology.com/analysis/joining-the-dots-how-gene-regulatory-network-tools-are-unearthing-drugs/
#
# i. What are the article's main points? Explain.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Ask one interesting question about this article that is relevant to network science.
#
# B. Please read ***Use Your Social Network as a Tool for Social Justice*** article and answer the following questions. (***Approximate Total Length: One Page***)
#
# Link: https://hbr.org/2020/07/use-your-social-network-as-a-tool-for-social-justice?utm_medium=email&utm_source=newsletter_daily&utm_campaign=mtod&referral=00203
#
# i. What are the article's main points? Explain.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Ask one interesting question about this article that is relevant to network science.

# %% [markdown]
# ## A1.
#
# ANSWER (TEXT): A good answer from one of your friends.
# ### A.
# i. The article explains how scientists have been increasingly interested in researching how “individual molecules interact with each other inside cells since the publication of the human genome” (Zamecnik 1). To analyze these interactions, they have been using the gene regulatory network. Scientists are using network science and technology to reconstruct and further understand the interactions between several molecules such as proteins, DNA, and RNA. By understanding the interactions between these molecules, the study of drugs can improve. For example, Zamecnik explains that “these algorithmic approaches are now being applied to develop and repurpose drugs.”
# GRN interference is introduced due to its large impact on disease. GRN interference “not only quickly estimates which existing drugs could impact a disease, but could also set the parameters for the creation of novel drugs” (Zamecnik 2). So, network interference could help reason on what effect a drug would have on a disease. EGRET, a network science tool was released in February, and is considered a “network zoo” which “features different GRN inference software named after creatures” (Zamecnik 2). This tool is vital in assisting and understanding complex data in relation to clinical impact and the modern study of science. However, because data is becoming more and more complex, finding the most crucial information is still a challenge for the overall field. Zemcnik explains that GRN is being used at Columbia University to repurpose cancer drugs, and for clinical trials for patients diagnosed with various cancers.
# Using these tools for collaboration, The Columbia University Medical Centre is using the data they find to build models of each cancer. These models help further identify “the master regulators responsible for cancer transcription and tumor maintenance” (Zamecnik 3). Through this system, scientists discover the drug’s pharmacology. After this identification, drugs are tested to see their effect in relation to the tumors in a patient. This testing approach is being used for pancreatic cancer patients as well. Depending on the tumor, their samples are used to identify which treatment is most beneficial. Califano, head of his team, explains that they have already seen answers in mice transplanted with tumors. By engaging in these tests and research, scientists and doctors will be able to develop successful cancer treatments and create more precise and high-success rated drugs.
# Although GRN is a very useful tool, it comes with the challenge of finding the “right” data. Because the data is so complex, sometimes there is too much information, and sometimes there is not enough relevant information. So, while these network science models will provide data, the scientists and doctors are the one’s to interpret it, which can lead to bias. To use these models for clinical research and approaches, the complexity needs to be reduced and become more user-friendly. This challenge can be seen as a “feature selection problem, a phenomenon also seen in other areas like statistics” (Zamecnik 3). Unnecessary details should be removed from the data to have the most accurate results and findings. While network science is assisting in the showing and understanding of a drug’s mechanism, the challenge of finding the needed data is still something that needs to be worked on before applying the data for clinical use.
#
# ii.
# While reading this article, I was surprised and fascinated about the way that network science can assist in the repurposing of drugs and cures of diseases such as cancer. For example, “Nordling says that this would be especially valuable in developing new treatments for cancer where mutations in the genome play a key role” (Zamecnik 2). This quote is referring to GRN, the network science tool used for clinical research and impact. What makes this part of the article so interesting is really understanding the role that technology plays in understanding specific drugs and diseases. This further shows how important it is to make use of network science software and tools, because it can lead scientists in finding a cure for diseases like cancer, which is a disease that over 600,000 people die from each year. It can also lead scientists in finding the most beneficial and effective drugs for patients diagnosed with diseases such as cancer. So, while networks can be used to study businesses, collaborations, and social networks, they can also be used to understand the effectiveness of drugs and can help lead to cures that can affect the world’s health deeply which is really fascinating.
#
# iii.
# Because data provided is very complex, can narrowing down data lead to the loss of important information that could potentially provide necessary and useful information for clinical purposes? How can we really figure out which data is useful and unuseful? Is having too much information really a problem? Wouldn’t scientists rather know more than know less?
#
# ### B.
#
# i. The article “Use Your Social Network as a Tool for Social Justice” talks about how we can use our social networks to take action in protesting for matters we believe in, such as the Black Lives Matter movement. The influence of one person is much stronger than we may think. For example, “your ideas and behaviors ripple out from you, influencing your friends, friends of friends whom you may not even know, and friends of those friends as well” (Brands, Rattan 1). Our sphere of influence can help us contribute to anti-racism and anti-sexism movements.
# Because we are such a social species, our survival is based on grouping, not individuality. We as humans are more likely to support and believe in something if our friend supports and believes in it too.
#
# Because we will most likely adopt the same views as our friends, we have more than enough influence in places such as a workplace. To spread a message, such as anti-sexism, all we need to do is communicate and engage in conversation with people who we believe need to hear it. Once they hear your opinion, they will be influenced as well- that is how humans work.
#
# Human networks hold a lot of power, so the way that we communicate and spread our message is very important. For example, if you start to notice issues in relation to bias in your workplace, you may intervene and “end by emphasizing anti-bias values and the majority’s responsibility for addressing and fixing the problem” (Brands, Rattan 2). By speaking out, you are not only standing up for yourself, but you are creating a social movement that will help fix the overall bias problem in your workplace.
#
# The article then explains how it is important to empower women and minorities by including them in your social network. While women and minorities want to confront comments that are hurtful to them, they may feel scared because of their professional and social relationships. Studies have shown that how central a woman is in a network predicted the likeness of them speaking up and confronting gender bias. In addition, these central women tend to believe that “their coworkers are similarly offended by gender bias and support their confronting it” (Brands, Rattan 2). Overall, even if you don’t hear the hurtful and biased comment, speaking up on behalf of colleagues can empower them to speak out later.
#
# To transform a social network, men participate in an active inclusion approach. This approach explains that as a man, you must make an effort to bring women and racial minorities into your network. This means asking them for opinions, advice, and including them in discussions. These interactions will allow men to learn more about the realities of life, and further understand how minorities live in a world and society with bias. This approach will allow minorities and women to share the reality of their experiences while feeling comfortable. These interactions should make them feel equal, without the worry of feeling judged. Overall, active inclusion provides an overwhelming amount of support for women and minority colleagues.
# There is lots of bias in today’s workforce. This inclusion will enforce you to provide opportunities and job offers to women or racial minorities instead of giving it to yourself, as well as allow you to make new relationships. It is time to use our social networks as an advantage to create a more equal and inclusive world and workforce, and understanding our privilege is the way to make things more equal for all women and minorities.
#
# ii.
# A quote that stood out to me was “this is the essence of anti-racism and anti sexism work: giving up your privilege to make things more equitable” (Brands, Rattan 3). What made this quote stand out to me was the word “privilege”. It is so important to understand that minorities and women are not receiving equal treatment in the workforce, and to get rid of this inequality, people have to understand the privilege that they have. The article then explains how when a man is provided a project or asked to do something for his company, instead of him taking it, he should give it up and offer the opportunity to a woman or racial minority. Simply offering up a project will allow them to feel more equal and take part in an opportunity that can grow their career. Practicing active inclusion is so important, so understanding privilege will further diminish the inequality in the modern workforce that is so prominent today, as well as provide opportunity for women and minorities that feel disadvantaged.
#
# iii. What is the most beneficial and strategic way to create a social network when fighting for social justice? Through a survey? Opinion? Using research?

# %% [markdown]
# ## Q2. (10 pts)
#
# In less than three pages please answer the following questions.
#
# A.	Describe a research question that you can ask for which network community analysis would be appropriate. Find a network dataset that you can answer this question. You can find the dataset and then decide on a research question also. On Moodle, I provided instructions for uploading a dataset to a Python notebook. Please note that a dataset with node labels (e.g., group, gender, race,...) maybe better for network community analysis. The question can be about anything. Nonetheless, only the most challenging and creative examples will be given full credit.
#
# ***Note: I provided a sample dataset on Moodle. If you are interested in American football you can use that dataset. The dataset contains the network of American football games
# between Division IA colleges during regular season Fall 2000, as compiled by M. Girvan and M. Newman.  The nodes have group values that indicate to which conferences they belong.  The groups are as follows:***
#
#   ***0 = Atlantic Coast,
#   1 = Big East,
#   2 = Big Ten,
#   3 = Big Twelve,
#   4 = Conference USA,
#   5 = Independents,
#   6 = Mid-American,
#   7 = Mountain West,
#   8 = Pacific Ten,
#   9 = Southeastern,
#  10 = Sun Belt,
#  11 = Western Athletic.***
#
#
#
# B.	Conduct network analysis and interpret the findings. Your response should be well-organized and demonstrate your knowledge of network science. It should include any relevant output, such as, but not limited to,
#
# i. Network community analysis: E.g., How many communities are optimal for your network? Which community analysis method works better?
#
# ii. A summary of other relevant network analysis (e.g., centrality,...)
#
# iii. Professional looking network plot(s).
#
# iv.	A professional-looking summary of your network analysis results
#
# v. A short discussion of the implications of your results.

# %% [markdown]
# ## A2.
#
# ANSWER (TEXT): A sample answer from one of your friends, modified.
# ## Research Question:
# Even though most teams are playing each other/interacting with each other, what could be a possible reason for subgroups to form?
# Is there a “mediator” team that interacts with at least one node from every other community?
# What could this imply for the dynamics of American Division IA football league in Fall 2000, and in general?
#
#
# ## Network Summary:
# This network provides information of American football games between colleges during the Fall 2000 season. As seen above, there are formed communities that are important and interesting to analyze when learning about the football teams and how they are structured. This network has 115 nodes, and 613 edges. It contains one connected component, as seen above, since there are no nodes that are disconnected from the entirety of the network.
#
# ## i. Network Community Analysis:
# The initial plot of this football network on Gephi reveals the 12 communities (conferences) that each team belonged to. However, it seems as though specific teams/regions interacted more often with other specific teams/regions. This could be due to the fact that each time a team wins, they advance further. **So, it is expected to see that some teams interacted more with other teams, as this indicates the success of the team.**

# %% [markdown]
# I decided to further analyze these communities by calculating the modularity of the network. Modularity is used as a measure for how good a clustering is. In other words, modularity measures the strength of a division of a network into groups. So, networks with high modularity have dense or strong connections within groupings, but smaller and more sparse connections with nodes in different modules. It has been noted that a “good” modularity score falls within 0.3-0.7 in real networks.
#
# **Using the Girvan Newman approach,** the modularity score of this American football network is 0.59. This indicates that there is significant and strong community structure in this network, which is visible in the below visualization, as groups of nodes are grouped together based on the teams that they play. When glancing at it, it looks like there are around 10 communities. A further examination of the subgroups formed reveals that the partitioning is quite similar to the original conferences. This shows that the interactions between two regions/teams are important because the more that the teams play each other, the more community structure they obtain. Because the modularity is not close to 0, the community structure is not random.
#
# Using the Girvan-Newman approach, I detected communities by progressively removing edges from the original graph. This allowed me to analyze how modularity and community structure would change (increase, decrease, or stay the same) based on removing the edge with high betweenness centrality (bridge node/team). As seen below, I observed that the modularity decreases as the number of communities increase. This indicates that as more clusters/groupings are being formed, communities become weaker. Through this dendrogram, I am able to see that tightly knit communities are broken as the edge with the highest betweenness centrality is removed. **This analysis method is helpful in understanding the underlying community structure because by removing the edges with high betweenness, previously formed communities are separated.** However, the Girvan Newman approach does not indicate the optimal number of clusters in a network. Therefore, I decided to analyze different approaches further. When looking closely, the modularity is the highest around 9 groups. Overall, when removing edges with high betweenness, community structure decreases, as seen through the visualization below. So, without edges with high betweenness centrality, community structure within this American Football network cannot be obtained, showing how the most influential edges keep the communities strong in this network.
#
# The Girvan Newman approach also allowed me to visualize the communities through modularity. The below visualization is the final partition of the network using the Girvan Newman Method. At K=9, there is the highest community structure. So, Because K = 9 had the highest modularity score, I used Girvan-Newman’s algorithm partitions to place the network in 9 distinct communities.
#
# **Using the Label Propagation Algorithm,** I was further able to analyze communities through the assigning of labels. What makes this approach interesting is that every node is initialized with a unique label, and throughout the algorithm, a label is given to a node that appears most often among its neighbors. The algorithm stops as soon as communities are found, meaning that each node has the label that appears most often with its neighbors. Through this algorithm, this network obtained 9 communities. The modularity was calculated to be 0.55, which is similar to Girvan-Newman’s approach, but a little lower. Visualizing the subgraphs made it easier to see the communities created by this algorithm, to see which teams interacted/grouped with which teams. After plotting the subgraphs, I was able to see the subgraphs much better based on Label Propagation. These subgroups are very similar to the partitioning done by Girvan-Newman, give or take 2 teams or so that are placed differently. This is very interesting that Label Propagation and Girvan-Newman produces similar results, which makes sense for this case as the assumption for both methods is an edge connecting two nodes carry a notion of similarity.
#
# **Using the Louvain method,** I was able to use the modularity score for each community, while merging the communities into a single node. This would allow me to evaluate how much more densely connected the nodes within a community are, compared to how they would be in a random network. When using this method, the network obtained a modularity score of 0.6, and found 10 communities. This is expected because the modularity score is a little bit higher when using the Louvain method, since this method in specific, groups small communities into one node through the modularity measures. Using the Label Propagation algorithm, it created 9 communities, and using the Louvain method it created 10 communities. This difference was interesting to note, as the community with id 7 (Mountain West conference) is successfully detected by Louvain, but ignored by other methods. I want to analyze other relevant network features to look deeper into this.

# %% [markdown]
# ## ii. General Network Analysis
# ## Centrality Analysis:
# The nodes with the largest degree measures of 12 were Florida State, Brigham Young, Iowa, Kansas State, Texas Tech, Penn State, Southern California, Wisconsin, Southern Methodist, Nevada, Tulsa, and Nevada Las Vegas. This makes sense because when visually analyzing the network, the teams are scattered as part of different communities/conference groups. So, there is at least one high-degree/central team part of each community, which further supports/suggests that there are communities and divides, even though all teams are interconnected. **This is also expected because there is at least one team from each conference that advances, since all conferences are playing against each other.** Each time a team wins, they advance in the competition. The node with the largest closeness centrality was Louisiana Tech.
# This indicates that Louisiana Tech was closest to all other teams in the network, and can reach the other teams within a short distance. So, Louisiana Tech played the majority of other teams in the conferences, indicating that Louisiana Tech won most of their games. The team with the largest harmonic centrality was Navy with a measure of 0.482. This indicates that out of all teams in the network, Navy could spread information and communicate the fastest and is also close to other teams. The team with the highest betweenness centrality was Notre Dame with a measure of 215. This indicates that Notre Dame is the “bridge” node in the network, meaning they competed with most other teams, also indicating this team's success. The node with the largest pagerank centrality was Texas Tech with a measure of 0.0096. This indicates that Texas Tech has a large number of connections to other teams, and is also connected to high-degree teams. This makes sense because when looking at Texas Tech visually in the network, it has the highest degree in its community, indicating that Texas Tech is a central team part of its community, and has been winning lots of games and advancing through the conference.
#
# Overall, there is no one specific node that dominates all of the centrality measures in terms of maximum. This further proves that there are communities present in this network, because in each community, there is a different team that holds a high measure. For instance, since there are 11 teams that hold the highest degree measure of 12, and they are scattered in different communities, this indicates that there is at least one node with a high degree in each community. In this conference, communities play against each other, so having a node with a high degree is expected since this indicates that this team has been advancing the most and winning most games against other communities.
#
# ## Path Length:
# The average path length of this network is about 2.5. This indicates that on average, it takes about a path of length 2-3 to go from one node to another. Average path length is a way to measure the efficiency or closeness of the nodes in a network, therefore because this measure is pretty small, the number of teams/nodes you have to go through to reach another node is 2-3. This indicates that overall, because the network is one connected component, it would not take long to reach another team in the network. This indicates that while teams within a conference played against one another at first, at higher rounds in the league teams in different conferences may be matched randomly through lottery to ensure fairness in a sports league.
#
# ## Clustering Coefficient:
# The average clustering coefficient of this network is 0.4. This indicates that on average, people in this network are clustered. This measure further proves the idea of the community structure in this network. Because 0.4 is not close to 0, there is significant clustering in this network, and this is because certain teams group with other teams when playing against them in football. The global clustering coefficient is also around 0.4. Because this is not close to 1, this indicates that the network is not fully connected. So, there are smaller groups/communities within the network, which is expected since this is a network representing teams in all different conferences and how they play each other in football throughout the competition.
#
# ## Degree Assortativity:
# The degree assortativity of this network is positive, and measures to be 0.16. Because this is a positive measure, this indicates that teams with high degrees are connected to other teams with high degrees. **This can indicate that the teams who make it far in the conference by winning the most amount of games will play other teams in other conferences who won the most amount of games.** This positive measure is expected, because teams that win the most will play other teams that win the most games.
#
# ## Degree Distribution:
# The degree distribution of this network is more of a Poisson distribution. This is expected because the average degree is 10.661. This network is in more of the random regime because since there are communities, there is no one central hub. Also, this network is based on football matches. As teams advance, they interact with more and more teams. Because of the way that the football league is structured, one team cannot have an exponentially greater amount of matches than other teams. You have to win in order to advance, therefore this distribution is expected.

# %% [markdown]
# ## iii. Professional Gephi Plot:
#
# ![Picture1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## iv. Summary and Implications of Results:
# Louisiana Tech can be considered a mediator node in this network, because when analyzing it on Gephi (as seen below), it is evident that it connects to at least one other node in other communities. Additionally, Louisiana Tech has a very high betweenness centrality measure of 185. This indicates that it is seen as a “bridge node”. So, even though the teams are split up into communities, there is still a possibility for a node to connect to and play at least one other node/team in other communities, which is a research question I was interested in, in regards to this network.
#
# In addition, I was able to determine the dynamics of this league regarding how teams played internally within a conference and externally as they advanced in the league.
#
# I was interested in what could be the reason for subgroupings to form in an American football conference. After analyzing, I realized that there could be multiple reasons behind these subgroupings. The first reason is the split up conferences. All of the teams are split up into different conferences, making them more likely to form communities with teams in their conferences, rather than interacting with teams in other conferences. Additionally, links and groupings could form based on the success of the team. If the team wins more football games, they are more likely to make more connections with other high degree teams in other conferences/communities, as they will be playing more teams and advancing. Overall, it is common for social networks and human networks to create sub groupings and communities, and this network portrays this idea through American football and the advancement of teams.

# %%
# ANSWER (CODE)
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import networkx as nx
import math
import plotly.express as px
import pandas as pd
import numpy as np

# %%
# A function that provides some network summary information.
def get_graph_info(graph):
    print("Number of nodes:", graph.number_of_nodes())
    print("Number of edges:", graph.number_of_edges())
    if type(graph) == nx.classes.digraph.DiGraph:
        print("Number of weakly connected components:", 
              len(list(nx.weakly_connected_components(graph))))
    else:
        print("Number of connected components:", len(list(nx.connected_components(graph))))
    print("Node degree:", dict(graph.degree()))

# %%
edges = pd.read_csv('football_edges.csv', skiprows = 1, sep=',', names=['Source', 'Target'])
nodes = pd.read_csv('football_nodes.csv', skiprows = 1, sep =',', names = ['Id','Label','Group'])

G = nx.from_pandas_edgelist(edges, 'Source', 'Target')
node_labels = dict(zip(nodes.Id, nodes.Label))
for i in sorted(G.nodes()):
    G.nodes[i]['Group'] = nodes.Group[i] # Please change i-1 to i if your node Ids start from 0
get_graph_info(G)
# Out:
# Number of nodes: 115
# Number of edges: 613
# Number of connected components: 1
# ...

# %%
# Colors for groups
num_groups=len(set(nodes.Group[:]))
color = plt.cm.rainbow(np.linspace(0, 1, num_groups))
color_dict = {}
keys = range(0, num_groups) # Use this if groups are numbered


color_dict = dict(zip(keys, color))

print(G.nodes(data="Group"))
# Function to assign color for node visualization
def create_node_colors_from_graph(graph, color_dict):
    node_colors = []
    for node, group in list(graph.nodes(data="Group")):
        if group in color_dict:
            node_colors.append(color_dict[group])
    return node_colors

# Get node colors for plotting
node_colors = create_node_colors_from_graph(G, color_dict)
print(node_colors)
# Out:
# [(1, 0), (0, 7), (3, 3), (2, 2), (4, 7), (5, 3), (6, 2), (7, 8), (8, 8), (9, 7), (10, 3), (11, 10), (13, 2), (12, 6), (14, 6), (15, 2), (16, 7), (17, 9), (18, 6), (19, 1), (20, 9), (21, 8), (22, 8), (23, 7), (24, 10), (25, 0), (26, 6), (27, 9), (28, 11), (29, 1), (30, 1), (31, 6), (32, 2), (33, 0), (34, 6), (35, 1), (36, 5), (37, 0), (38, 6), (39, 2), (40, 3), (41, 7), (42, 5), (43, 6), (44, 4), (45, 0), (46, 11), (47, 2), (48, 4), (49, 11), (50, 10), (51, 8), (52, 3), (53, 11), (54, 6), (55, 1), (56, 9), (57, 4), (58, 11), (59, 10), (60, 2), (61, 6), (62, 9), (63, 10), (64, 2), (65, 9), (66, 4), (67, 11), (68, 8), (69, 10), (70, 9), (71, 6), (72, 3), (73, 11), (74, 3), (75, 4), (76, 9), (77, 8), (78, 8), (79, 1), (80, 5), (81, 3), (82, 5), (83, 11), (84, 3), (85, 6), (86, 4), (87, 9), (88, 11), (89, 0), (90, 5), (91, 4), (92, 4), (93, 7), (94, 1), (95, 9), (96, 9), (97, 10), (98, 3), (99, 6), (100, 2), (101, 1), (102, 3), (103, 0), (104, 7), (105, 0), (106, 2), (107, 3), (108, 8), (
# ...

# %%
# Create visualization
pos = nx.spring_layout(G, 
                       k=0.2, iterations=50,
                       seed=2)

plt.figure(1,figsize=(12,12)) 
nx.draw(G,
        pos = pos,
        node_color=node_colors,
        node_size=1000,
        with_labels=True,
        labels=node_labels, # You can remove the first # in this line to get labels in the plot
        font_size = 10,
        font_color='black')

# Make legend
for n in range(0, num_groups):
    plt.plot([], [], 'bo', markersize = 30, color = color[n], label = keys[n])
plt.legend(labelspacing = 5, loc='lower left', bbox_to_anchor=(0, 1), frameon = False)

plt.show()

# %%
# Function to return a node's neighbor nodes as a list
def get_neighbors(graph, node):
    return [n for n in graph.neighbors(node)]

# Function to return the subgraph containing 2 nodes' common neighbors
def get_common_neighbor_subgraph(graph, source, target):
    nodes = [source, target] + list(nx.common_neighbors(G, source, target))
    return graph.subgraph(nodes)

# %% [markdown]
# # Girvan-Neman

# %%
from networkx.algorithms.community.centrality import girvan_newman
import networkx.algorithms.community as nx_comm

# %%
# Find communities using Girvan Newman method
girvan_newman_communities = list(girvan_newman(G))
modularity_df = pd.DataFrame([[k+1, round(nx_comm.modularity(G, girvan_newman_communities[k]), 6)]
                for k in range(len(girvan_newman_communities))],
                            columns=["k", "modularity"])
modularity_df.plot.bar(x="k", figsize=(10,6), title="Girvan-Newman Community Detection Modularity Trend");

# %%
# Function to create node color list for communities
# When there are more than 6 colors, visualization can be confusing for human
def create_community_node_colors(graph, communities):
    color = plt.cm.rainbow(np.linspace(0, 1, len(communities)))
    node_colors = []
    # Iterate each node in the graph and find which community it belongs to
    # If the current node is found at a specific community, 
    # add color to the node_colors list
    for node in graph:
        current_community_index = 0
        for community in communities:
            if node in community:
                node_colors.append(color[current_community_index])
                break
            current_community_index += 1
    return node_colors

def visualize_communities(graph, communities):
    # create visualization
    node_colors = create_community_node_colors(graph, communities)
    modularity = round(nx_comm.modularity(graph, communities), 6)
    title = f"Community Visualization of {len(communities)} communities with modularity of {modularity}"
    pos = nx.spring_layout(graph, 
                           k=0.3, iterations=50,
                           seed=2)
    plt.figure(1,figsize=(10,6)) 
    nx.draw(graph,
            pos = pos,
            node_size=1000,
            node_color=node_colors,
            with_labels=True,
            labels=node_labels, # You can remove the first # in this line to get labels in the plot
            font_size = 10,
            font_color='black')
    plt.title(title)
    plt.show()

# %%
visualize_communities(G, girvan_newman_communities[7])

# %% [markdown]
# # Label Propagation:

# %%
from networkx.algorithms.community.label_propagation import label_propagation_communities

# %%
# Find communities
label_prop_communities = list(label_propagation_communities(G))
visualize_communities(G, label_prop_communities)

# %%
def visualize_subgraph(graph, subgraph_nodes, node_color):
    # get subgraph
    subgraph = nx.subgraph(graph, subgraph_nodes)

    # create visualization
    node_colors = [node_color] * len(subgraph_nodes)
    title = f"Community Partition Subgraph"
    pos = nx.spring_layout(subgraph, 
                           k=0.3, iterations=50,
                           seed=2)

    plt.figure(1,figsize=(5,5)) 
    nx.draw(subgraph,
            pos = pos,
            node_size=1000,
            node_color=node_colors,
            with_labels=True,
            labels=dict((k, node_labels[k]) for k in subgraph_nodes), # You can add a # to suppres labels in the plot
            font_size = 10,
            font_color='black')
    plt.title(title)
    plt.show()

# %%
color = plt.cm.rainbow(np.linspace(0, 1, len(label_prop_communities)))
colors = color
for i in range(len(label_prop_communities)):
    visualize_subgraph(G, label_prop_communities[i], colors[i])

# %% [markdown]
# # Louvain

# %%
from community import community_louvain

# %%
# Convert the python-louvain package output to 
# NetworkX package community function output format
def get_louvain_communities(graph, random_state=1):
    louvain_partition_dict = community_louvain.best_partition(graph, random_state=random_state)
    unique_partition_labels = list(set(louvain_partition_dict.values()))
    communities = [[] for i in range(len(unique_partition_labels))]
    for node in louvain_partition_dict.keys():
        communities[louvain_partition_dict[node]].append(node)
    return communities

# %%
# get communities using louvain algorithm
louvain_communities = get_louvain_communities(G, random_state=1)
visualize_communities(G, louvain_communities)

# %%
color = plt.cm.rainbow(np.linspace(0, 1, len(louvain_communities)))
colors = color
for i in range(len(louvain_communities)):
    visualize_subgraph(G, louvain_communities[i], colors[i])

# %% [markdown]
# # General Network Analysis

# %%
from itertools import combinations

# %%
def global_clustering_coefficient(G):	# A function for finding global clustering coefficient
  open_triangle_nodes = []
  for node in list(G.nodes):
    neighbors = set(G.neighbors(node))
    for n1, n2 in combinations(neighbors, 2):
      if not G.has_edge(n1, n2): open_triangle_nodes.append([n1, node, n2])

  triangles=sum(nx.triangles(G).values())/3
  return 3*triangles/(3*triangles+len(open_triangle_nodes))

# %%
print("Total number of nodes (N): ", G.number_of_nodes())                 # The number of nodes (N) 
print("Total number of links (L): ", G.number_of_edges())                 # The number of links (L)
print("Average Degree (<k>): ", 2*G.number_of_edges()/G.number_of_nodes()) # The average degree (<k>) = 2*L / N
GCC = sorted(nx.connected_components(G), key=len, reverse=True)
G0 = G.subgraph(GCC[0])
print("Size of the giant component(S): ", G0.number_of_nodes()/G.number_of_nodes())      # Giant Component Size     
print("The average path length (l): ", nx.average_shortest_path_length(G0, method='bellman-ford'))   # Average Path Length 
# NOTE THAT AVERAGE PATH LENGTH RUN MIGHT TAKE VERY LONG FOR LARGE NETWORKS. YOU CAN "#" THE ABOVE LINE IF THAT IS THE CASE.
print("Global clustering coefficient (C): ", global_clustering_coefficient(G0))  # Global clustering coefficient
print("Average clustering coefficient (CWS): ", nx.average_clustering(G0))       # Average local clustering coefficient
print("Assortativity based on degree (r) :", nx.degree_assortativity_coefficient(G0)) # Assortativity based on degree
# Out:
# Total number of nodes (N):  115
# Total number of links (L):  613
# Average Degree (<k>):  10.660869565217391
# Size of the giant component(S):  1.0
# The average path length (l):  2.5081617086193746
# Global clustering coefficient (C):  0.4072398190045249
# Average clustering coefficient (CWS):  0.40321601104209814
# Assortativity based on degree (r) : 0.16244224957444287

# %%
# Visualize function
def degree_distribution(G):
  fig = plt.figure("Degree of an undirected network", figsize=(20, 12))
  axgrid = fig.add_gridspec(5, 4)
  degree_sequence = sorted((d for n, d in G.degree()), reverse=True) 
  ax2 = fig.add_subplot(axgrid[3:, 2:]) 
  ax2.bar(*np.unique(degree_sequence, return_counts=True)) 
  ax2.set_title("Degree Distribution Histogram") 
  ax2.set_xlabel("Degree")
  ax2.set_ylabel("# of Nodes") 
  fig.tight_layout() 
  plt.show()

degree_distribution(G)

# %%
def find_highest_centrality_nodes(centralities, centrality_metric): # Function for finding the highest centrality scores
  itemMaxValue = max(centralities.items(), key=lambda x: x[1]) 
  print('The maximum', centrality_metric, 'centrality score in the network : ', itemMaxValue[1]) 
  listOfKeys = list()
  # Iterate over all the items in dictionary to find keys with max value
  for key, value in centralities.items():
    if value == itemMaxValue[1]: 
        listOfKeys.append(key)
        print('Nodes with the maximum', centrality_metric, 'centrality score: ', listOfKeys)

# %%
centralities = nx.degree_centrality(G)	# Find the degree centrality of all nodes
print("The degree centrality for all nodes: ", centralities)	# All degree centrality of the nodes in the network G. find_highest_centrality_nodes(centralities,'degree')	# The nodes with highest degree centrality
 

centralities=nx.closeness_centrality(G)	# Find the closeness centrality of all nodes
print("The closeness centrality for all nodes: ", centralities)	
# All closeness centrality of the nodes in the network G.
find_highest_centrality_nodes(centralities,'closeness')	
# The nodes with highest closeness centrality	

centralities=nx.harmonic_centrality(G)	
# Find the harmonic centrality of all nodes
print("The harmonic centrality for all nodes: ", centralities)	
# All harmonic centrality of the nodes in the network G.
find_highest_centrality_nodes(centralities,'harmonic')	
# The nodes with highest harmonic centrality	

centralities=nx.betweenness_centrality(G)	
# Find betweenness centrality of all nodes
print("The betweenness centrality for all nodes: ", centralities)	
# All betweenness centrality of the nodes in the network G.
find_highest_centrality_nodes(centralities,'betweenness')	
# The nodes with highest betweenness centrality	

centralities=nx.eigenvector_centrality(G)	
# Find eigenvector centrality of all nodes
print("The eigenvector centrality for all nodes: ", centralities)	
# All eigenvector centrality of the nodes in the network G.
find_highest_centrality_nodes(centralities,'eigenvector')	
# The nodes with highest eigenvector centrality	

centralities=nx.pagerank(G)	
#Find the pagerank centrality of all nodes
print("The pagerank centrality for all nodes: ", centralities)	
#All pagerank centrality of the nodes in the network G.
find_highest_centrality_nodes(centralities,'pagerank')	
#The nodes with highest pagerank centrality
# Out:
# The degree centrality for all nodes:  {1: 0.10526315789473684, 0: 0.10526315789473684, 3: 0.10526315789473684, 2: 0.10526315789473684, 4: 0.09649122807017543, 5: 0.10526315789473684, 6: 0.10526315789473684, 7: 0.10526315789473684, 8: 0.09649122807017543, 9: 0.09649122807017543, 10: 0.08771929824561403, 11: 0.08771929824561403, 13: 0.09649122807017543, 12: 0.08771929824561403, 14: 0.08771929824561403, 15: 0.10526315789473684, 16: 0.09649122807017543, 17: 0.09649122807017543, 18: 0.09649122807017543, 19: 0.09649122807017543, 20: 0.09649122807017543, 21: 0.09649122807017543, 22: 0.09649122807017543, 23: 0.09649122807017543, 24: 0.08771929824561403, 25: 0.09649122807017543, 26: 0.08771929824561403, 27: 0.09649122807017543, 28: 0.07894736842105263, 29: 0.09649122807017543, 30: 0.09649122807017543, 31: 0.09649122807017543, 32: 0.09649122807017543, 33: 0.08771929824561403, 34: 0.09649122807017543, 35: 0.09649122807017543, 36: 0.07017543859649122, 37: 0.09649122807017543, 38: 0.0964912280701
# ...

# %% [markdown]
# ## Q3. (2 pts)
#
# In a Big Brother society, the thought police wants to follow a "divide and conquer" strategy by fragmenting the social network into isolated components. You belong to the resistance and want to foil their plans. There are rumours that the police wants to detain individuals that have many friends. ***The resistance puts you in charge to decide who to protect?*** To decide you simulate an attack on your network, by removing the nodes that have the largest degree (See the plot below). Determine how many individuals you should protect. You can assume that there are $N=6000$ people in the social network.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Scale-free Network Under Attack***
#
# The probability that a node belongs to the largest connected component in your network under attack (purple) and under random failures (green). For an attack we remove the nodes in a decreasing order of their degree: we start with the biggest hub, followed by the next biggest and so on. In the case of failures the order in which we choose the nodes is random, independent of the node’s degree.

# %% [markdown]
# ## A3.
#
# ANSWER (TEXT):
#
# f^c, the point that the probability that a node belongs to the largest connected component in the network is 0%, marks the proportion of nodes needed to be removed for the network to be fragmented. The resistance should protect 17% of the nodes because after that point, the probability of a node belonging to a hub is zero. 17% of 6000 is 1,020, so the resistance group should protect 1,020 individuals.
#
# *Answers can range from 960~1200, as f^c can be estimated in the range 16%-20%.

# %% [markdown]
# ## Q4. (5 pts)
#
# **A.** Describe a real-world problem for which you would prefer to use network robustness analysis. In a paragraph, explain the problem's significance. Also, explain how you intend to approach solving this problem.
#
# **B.** Describe a real-world problem for which you would prefer to use network community analysis. In a paragraph, explain the problem's significance. Also, explain how you intend to approach solving this problem.

# %% [markdown]
# ## A4.
#
# ANSWER (TEXT): A good answer from your friend. Answer should demonstrate depth of understanding and show thoughtful questions.
#
# ## A.
# Due to harmful human actions and activity, many species are becoming extinct. The human population is causing extinction by ruining natural habitats through hunting, polluting, and overharvesting. For example, according to Britannica, the Passenger Pigeon was extinct because hunters raided their nesting grounds. While this is just one example, there are over 500 species that have become extinct due to detrimental human actions, and the number is not stopping anytime soon. This is a significant real-world problem because our ecosystem becomes increasingly unhealthy every time a species goes extinct. Plant and animal species are the foundation of our ecosystems, so an ecosystem falls apart when a species becomes endangered. It is also expected that each time a species is lost, it triggers the loss of other species within its ecosystem.Network robustness is the capacity of a network to maintain connections when a node is removed for a specific reason, strategy, or attack. Network robustness is advantageous in ecology because it can provide insight into the particular reaction to disturbances of extinction.
# We can use network robustness analysis to solve this issue to see which human action is most detrimental to a specific species. When finding what action causes the most harm to the species, we can communicate with ecologists and higher authorities to attempt to stop this human action and protest to keep the species' ecosystem safe from human harm. We can also use network robustness analysis to predict when a species will become extinct. Predicting these failures will allow ecologists to be prepared and understand how long it takes for human actions to affect a larger species. Network robustness analysis can also help understand the food web that sustains each species and how removing a specific nutrient can hurt or help the ecosystem and species' survival.
#
# ## B.
# In today's world, many people disagree due to political views, which can cause divides and significant problems between social groups. Political tension is very prominent, and because humans are so interconnected, a disagreement can ruin relationships and friendships. A community is a locally dense connected subgraph in a network. We can use network community analysis to analyze political views and how humans tend to group with those with similar ideas. However, there will also be people who will not pay attention to political opinions and group with whoever they enjoy spending time with, regardless of their views. This problem of division due to political views can be solved by understanding that there will be a mediator cluster. This mediator cluster includes interactions between individuals with all different opinions on politics. This mediator cluster can prove that even though people believe in different things, they can still interact and be friends with each other. Humans do not always have to separate because of a disagreement. The mediator group can slowly bring the divided groupings together, forming a larger cluster. This can solve tension in a community, prove that a community should be united regardless of political views, and provide the understanding that humans will never agree on everything, which is human nature. We can also analyze hierarchical clustering, remove the link with the largest centrality, and see how many connections are lost. This can show us if people's beliefs are swayed due to who they surround themselves with or if they genuinely believe in a specific political view. Overall, analyzing network communities can allow us to understand human behavior at a deeper level and get rid of a separation that can unite communities, like political views.

# %%
import pandas as pd
from sklearn.cluster import KMeans
df1 = pd.read_csv('GSE84635_old.csv') # LOAD THE DATASET. 
df2 = pd.read_csv('GSE84635_new.csv') # LOAD THE DATASET. 
X1 = df1.iloc[:, 1:].values
X2 = df2.iloc[:, 1:].values
print(X1.shape)
print(X2.shape)
# Out:
# (22011, 78)
# (78, 22011)

# %%
number_of_clusters = 3     # I USE 3 CLUSTERS HERE SINCE WE HAVE SEEN THAT 2 TO 3 CLUSTERS ARE SUGGESTED ABOVE
kmeans = KMeans(n_clusters = number_of_clusters, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X1)

df1_kmeans_c1 = df1[y_kmeans == 0]
print(len(df1_kmeans_c1))
df1_kmeans_c2 = df1[y_kmeans == 1]
print(len(df1_kmeans_c2))
df1_kmeans_c3 = df1[y_kmeans == 2]
print(len(df1_kmeans_c3))
# Out:
# 4542
# 10516
# 6953

# %%
number_of_clusters = 3     # I USE 3 CLUSTERS HERE SINCE WE HAVE SEEN THAT 2 TO 3 CLUSTERS ARE SUGGESTED ABOVE
kmeans = KMeans(n_clusters = number_of_clusters, init = 'k-means++', random_state = 42)
y_kmeans = kmeans.fit_predict(X2)

df2_kmeans_c1 = df2[y_kmeans == 0]
print(len(df2_kmeans_c1))
df2_kmeans_c2 = df2[y_kmeans == 1]
print(len(df2_kmeans_c2))
df2_kmeans_c3 = df2[y_kmeans == 2]
print(len(df2_kmeans_c3))
# Out:
# 40
# 24
# 14
