# %% [markdown]
# # ACTIVE LEARNING EXERCISE 5
# ## Networks: Friends, Terrorists, and Epidemics
# ## Due by 11:55pm on Friday, October 21, 2022
#
# ### Name:
# ### Group Member(s):
#
# ## GUIDELINES
# - You may either type or write out your responses. You should provide your own solutions for the questions. For the assignment you can use resources available to you (e.g., textbook, notes, your classmates, tutor, and Prof. Ay.)
# - To receive full credit, you must show all of your work and adhere to the formatting guidelines outlined here. Please keep in mind that some of the questions may be graded based on their completion.
# - Please write your name on your assignment. Submit the answers to questions electronically in one or more documents by uploading a PDF or set of images to Gradescope. If you submit a pdf file, please select each question and then click on the page(s) for that question. Instructions for submitting your work can be found in the posted video (https://www.youtube.com/watch?v=u-pK4GzpId0).
# - You are welcome to use Python and/or Gephi to perform calculations or check your work. Just be sure to include any equations and Python code (or Gephi screenshots) that you used.
# - You can use https://colab.research.google.com/ website to work on this notebook. After finishing your work you can download the notebook.
# - You can use a resource such as https://www.vertopal.com/en/convert/ipynb-to-pdf to convert your Python notebook to a pdf file.
# - You can use a resource such as https://combinepdf.com/ website to combine pdf files. For example if you want to combine your handwritten solutions with your answers that you created through a computer.
# - For the non-coding questions in this assignment, you may enter your responses beneath the question, or write your answers in a Word document and convert it to a pdf file, or write your answers by hand on a piece of paper, photograph it, and convert it to a pdf file.

# %% [markdown]
# ##Q1.
#
# **A. (3 pts)** Please read The Sixth Link: The 80/20 Rule chapter of the Linked book by Barabasi, and answer the following questions. (Approximate Total Length: One Page)
#
# i. What are the chapter's main points? Use examples from the book to explain it.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Ask three interesting questions about this chapter that is relevant to network science.
#
# **B. (3 pts)** Please read The Seventh Link: The Rich Get Richer chapter of the Linked book by Barabasi, and answer the following questions. (Approximate Total Length: One Page)
#
# i. What are the chapter's main points? Use examples from the book to explain it.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Ask three interesting questions about this chapter that is relevant to network science.

# %% [markdown]
# ## A1:
#
# A good answer from your friend:
#
# **Q1(A). The Sixth Link**
#
# i.	“The Sixth Link” chapter begins by introducing Vilfredo Pareto, an Italian Economist, and how he devoted his career and life to economics and science. His most important finding, “the three-volume Trattato, continues to be a source of inspiration and interpretation for
# economists and sociologists alike” (Barabasi 67). Pareto, who was also a gardener, realized that “80 percent of his peas were produced by only 20 percent of the peapods” (Barabasi 68). This observation turned into Murphy’s Law. For example, he observed that “80 percent of Italy’s land was owned by only 20 percent of the population” (Barabasi 68). Further, in relation to network science, “80 percent of links in Hollywood are connected to 30 percent of actors” (Barabasi 68).
#
#
# The idea of this 80/20 rule is introduced, and is a law that deals with complex systems that are considered special because of their properties.
# Barabasi then goes into explaining the power-law, which is a way to identify that most quantities in nature go along a bell curve. He provides an example of measuring a group of adult males and how “you will find that most people in your sample are between five and six feet tall” (Barabasi 69). If we create a histogram on this data, it will have a peak around these values.
# These bell curves are important because most quantities in nature follow this trend of peak distribution. However, power laws are different from bell curves in references to measuring heights. Power laws do not have a peak, and they are a continuously decreasing curve. This decreasing curve explains that “many small events coexist with a few large events'' (Barabasi 69). Overall, power laws indicate that there are many tiny events that coexist with some large events. In addition, in network science, power laws each have a unique exponent that indicates the degree exponent. Barabasi found that the Webpage creators “action forces the degree distribution to evade the bell curve,” (Barabasi 70) which tempted another approach to this problem. When further analyzing, scientists found that “the number of actors that had links to
# exactly k other actors decays following a power law” (Barabasi 70). Many other discoveries lead to the conclusion that many scientists actually follow the power-law which indicates that “the number of nodes with exactly k links follows a power law, each with a unique degree exponent that for most systems varies between two and three” (Barabasi 70).
#
# The chapter dives deeper into understanding the visual and structural differences between a random network (US roadmap) and a power-law degree distribution (airline routing map).
#
# When comparing both, the roadmap is a uniform network, and the airline map is not because of how some central hubs connect a large number of small airports. While analyzing, it was evident that the power law distribution abandons the idea of a scale because there is no one node that can be the characteristic of all nodes. Hence, power-law degree distribution is scale-free. While Erdos and Renyi’s random network theory claimed that the number of nodes with x links should decrease, this was “a much faster decay than that predicted by a power law,” (Barabasi 72) saying that hubs do not exist. However, when analyzing the Web, power laws required us to recognize all hubs; because most networks are scale-free, these hubs help determine stability, behavior, and define a real network's topology, so central hubs do exist.
#
# Although the phrase 80/20 was never used by Paretto, it is not certain where the term started. The chapter then mentions how Paretto was most proud of his observation that “roughly 80 percent of money is earned by only 20 percent of the population” (Barabasi 73). His observation is still thought to be true today. Barabasi explains that there is always a power law everytime we use the 80/20 rule, indicating that a few large events carry lots of importance. The
# understanding of power laws allowed scientists to understand the order and behavior of complex networks at a deeper level. These laws were a huge accomplishment and continue to be for
# complex networks.
#
# The chapter then goes into how scientists questioned how order emerges from disorder in nature. Like water transitioning from a liquid to a solid ice cube, Barabasi explained that this is an example of a transition from disorder to order. These states of water deal with phases of matter; the closer you are to the critical point (right at the transition), the more power laws operate. When a liquid reaches its transition point, it loses its identity because of the power law. Leo Kadanoff stated that “in the vicinity of the critical point we need to stop viewing atoms separately” (Barabasi 76). His statement led to the discovery of 9 different critical exponents all associated with a power law and the critical point. However, it wasn’t until physicist Kenneth Wilson came up with the theory of renormalization that Kadanoff’s theory made sense. Through scale invariance, his renormalization group “not only called for power laws but for the first time could predict the values of the two missing critical exponents as well” (Barabasi 77). After this observation, power laws were realized to be the “patent” of organization in complex systems- they were extremely important in all network science. To conclude, Barabasi’s main point through this chapter was to emphasize that power laws and understanding hubs are behind almost every transition behavior in complex systems.
#
# ii.	A quote that particularly stood out to me was that “80 percent of profits are produced by only 20 percent of the employees” (Barabasi 68). This data surprised me because of how little people contributed to a large number of profits. This forced me to think about what the other 80% of employees contribute to, if they do not contribute to any profits in a company. This further showed me how important it is to understand this 80/20 rule phenomenon, and how while it may seem that 100% of employees are contributing to profits and success, that is not the truth when analyzing network science and data. In addition to this surprising statistic Barabasi mentioned how “in most cases four-fifths of our efforts are largely irrelevant” (Barabasi 68). This was also surprising to me because four-fifths is over half, which is a large percentage. These phenomena and findings really surprised me, but as I kept reading I realized that what may seem to be true is not always true when analyzing power laws in relation to systems and complex networks.
#
# iii.
# 1.	What is a real-world example where the 80/20 rule does not apply? Like, when Barabasi states that “Though it might be tempting to infer that the 80/20 rule applies to just about anything, that would be a gross overstatement” (Barabasi 68).
#
# 2.	Is there a maximum or minimum number of big hubs that coexist in a network?
# 3.	Does the critical point vary for each system? At what specific point do power laws come into play during phase transition?

# %% [markdown]
# **Q1(B). The Seventh Link**
#
# i.	“The Seventh Link” chapter begins by talking about Barabasi’s visit to Porto. He explains that he had questions relevant to networks in his mind: one being the reason for hubs, and another being the reason for power laws. While at the time the Web was the only network mathematically proven to have hubs, his questions made sense. To gather information on more real networks to reach answers to his questions, he contacted professors and scientists. Barabasi and his graduate Reka decided to analyze a Hollywood actor database using the wiring diagram of a computer chip. Reka concluded that “in almost all systems, the tail of the distribution follows a power law” (Barabasi 81). Barabasi realized that if two completely different networks like the Web and the Hollywood Actor Network use the power law, then this power law could
# apply to all networks somehow. This finding influenced Barabasi to write a paper on this subject, but when submitted, the editors rejected it because they believed that the paper wouldn’t attract a wide audience. Barabasi called the editor back and forced the editor to change his mind- he believed this subject was of more importance than people may first believe.
#
# The first part of Barabasi’s manuscript was about Erdos and Renyi’s random network theory, and how nodes are linked randomly to each other. However, he explains that the discovery of central hubs and power laws force scientists to discard random network theory and their assumptions.
#
# The chapter then goes into how real networks all share the feature of growth. An example being the Web, and how it is continuously growing every day. Although the Web somehow began with a one singular node, it is growing exponentially, with an increasing number of nodes every day. Similar to the Web, the Hollywood network is also booming, growing to over half-a million nodes. All real networks grow incrementally, forcing us to question Erdos-Renyi and Watts-Strogatz models due to their assumption that we have a fixed number of nodes. Because they believe networks are static and the nodes are fixed, their models are incorrect for real networks.
#
# Barabasi then talks about how to model a growing network. To represent this, we
# continue linking nodes to each other as we add them. For example, while a simple algorithm network’s nodes are not equivalent to each other, at each moment, “all nodes have an equal chance to be linked to, resulting in a clear advantage for the senior nodes” (Barabasi 84).
# However, the first nodes are considered “richest” because they have the largest probability to create links, and the “poorest” node will be the last node, since it only has the opportunity for 2 links. Simulations convinced scientists that degree distribution explains the difference between scale-free networks and random models. So, Model A fails to account for central hubs and links. Therefore, power laws are more than just growth alone.
#
# The next subsections talks about preferential attachment, and how we as humans decide which websites to look at or link on the Web. When we choose which news article to read, “the random network model tells us that we select randomly from the list” (Barabasi 85). However, Barabasi disagrees with this random model, as he believes that we as humans choose between major hubs. The more known a news outlet is, the more linked they are. Therefore as humans, we are more likely to choose a news outlet such as CNN than a random newspaper we find on the web. Preferential attachment explains the phenomenon that when choosing between pages, we will choose to link to the more connected and known page, which is a common pattern.
#
# Preferential attachment is seen in many other networks as well, such as a Hollywood network when a producer will most likely choose an actor that is more known, or in other words, has more links. Networks like the WWW and Hollywood abandon the democratic character of random networks due to the fact that linking is never random in real networks. Linking is based on popularity, high connectedness, etc. The more connected a node is, the more wanted and
# attractive it is, explaining the prominent role of preferential attachment.
# To conclude, real networks are composed of the laws of growth and preferential
# attachment. Each network starts with one node and continuously expands. When nodes are added, they will link to nodes that have the most links, which is their preference. This discards random network theory, as no linking is actually ever random. The scale-free model proposed in 1999 explained the phenomenon of hubs and power laws. Growth gives an advantage to older nodes; the earlier a node enters the network, the more likely it is that additional nodes will connect to it. On the other hand, hubs are created through preferential attachment. All subsequent nodes will prefer to link to the earlier highly connected nodes. Therefore, the earlier nodes will generate into hubs, which explains the “rich-get-richer” phenomenon; the more connected a node is, the more links they will generate compared to later added nodes. This phenomenon leads to power laws, because “each node attracts new links at a rate proportional to the number of its current links” (Barabasi 88). Overall, growth and preferential attachment are necessary to generate power laws, otherwise the network will be static, which is highly uncommon.
#
# Barabasi concludes this chapter by talking about his work with Reka, and how he started investigating networks further by looking at internal links and the structure of scale-free networks. He mentions how Mendex and Dorogovtsev found that the older that the nodes get does not get rid of the power laws, but just affects the degree exponent. There were many important results toward the concept of power laws that help network scientists to this day.
# Beginning with the idea of networks being random and static, to realizing that networks are continuously changing and growing over time, the understanding of networks has improved tremendously. So, while a network will continuously grow, with preferential attachment and growth, the network will most likely maintain its central hub and structure. Understanding power laws and their importance allow scientists to understand this important conclusion and further
# analyze and understand real networks in modern day.
#
# ii.	A passage that stood out to me the most was reading about Erdos and Renyi’s random network theory model in relation to growth. I was surprised to learn that these scientists assumed that “the number of nodes is fixed and remains unchanged throughout the network’s life” (Barabasi 82). This assumption surprised me mostly because in life, everything is changing, nothing is static. From the day someone is born, everything changes. The way that they look, talk, eat, etc. Although this is a simple example, I continue to question how Erdos and Renyi came up with this invalid assumption, and what led them to make this specific assumption, because everything in the world changes in size everyday. Nothing ever stays completely the same or identical which is why the assumption of Erdos and Renyi surprised me the most.
#
# However, the understanding of power-laws disproved the validity of their random network theory which was interesting to read about as well, making this passage one that stood out the most to me.
#
# iii.
# 1.	Does random network theory provide any advantage to real networks, or can we
# completely disregard them when studying real networks due to their invalidity in certain aspects like growth?
# 2.	Is the first node always going to be the MOST interconnected node/hub? Or is it just very likely that it will be?
# 3.	Are there any examples of networks that are actually static and do not grow at all in network science?

# %% [markdown]
# ## Q2.
# ## The Structure of Real World Networks
#
# Analyze the structure of nine real world networks (Collaboration,
# Internet, Power Grid, Protein, Phone Calls, Citation, Metabolic, Email, WWW). The network datasets are provided on Moodle.
#
# **A. (2 pts)** Please create a summary table of the following network metrics: the number of nodes (N), the number of links (L), the average degree ($<k>$), the size of giant component (S), the average path length ($l$), the exponent $\alpha$ of power law degree distribution, the global clustering coefficient (C), average local clustering cefficient (CWS), and the assortativity coefficient by degree. (You can take a screen shot of your table and insert it to your answer. Please donot upload your code for this question.)
#
# **B. (4 pts)** Please make a comparison between the values you found in your table and those given in the lecture. Chapter 10 of Networks (by Mark Newman) contains the table that was used in the lecture. I'm particularly interested in your comparison of the networks. ***Example:*** Assortativity by degree, for instance, is typically positive for social networks. Have you noticed that? Do you see that the average path length for real networks is short? For a discussion of the structure of networks in the real world, please check lecture 6 (and Chapter 10 of Networks book by Mark Newman).

# %% [markdown]
# ### A2.
#
# ANSWER (TEXT):
# ![Screen Shot 2022-10-30 at 19.40.36.png](data:image/png;base64,...)

# %% [markdown]
# ### Nodes(N):
# In general, Newman’s networks were larger. For example, for the phone call network, the number of nodes Newman had were 47,000,000. For example, the number of nodes for the Barabasi Phone Call network was 36,595.
#
# ### Largest Component Size:
# The largest component size of all types of networks seem to range from 0.8-1, i.e. the largest component has 80-100% of the nodes. Information Networks and Technological Networks seem to be pretty static with their measures, close to 1.0, indicating almost an absence of isolated nodes for every network.
#
# The measure of 1 makes sense for Power Grid, WWW, and Metabolic makes sense, because these are highly connected real networks. Mark Newman also mentions how for undirected networks, like the Power Grid Network, “there is a large component that fills most of the network - usually more than half and not infrequently over 90% of the nodes.” (Newman 319). For directed networks, there are both weakly connected and strongly connected components. Because directed networks have in and out components, strongly connected components can be reached from smaller components.
#
# ### Average Distance:
# When analyzing average distance, biological networks seem to have relatively shorter distances as a whole. However, Information, Social and Technological networks have relatively higher measures for average distance.
#
# In general, when analyzing average path length for real networks, the pattern is that the lengths are relatively short as a result of the small-world effect. The paths being short in real networks indicates how quickly information and sickness (like disease) can be spread extremely quickly.
#
# ### Alpha:
# When analyzing the alpha measurements, most are between 1-3, and positive for all networks. Compared to the networks that Newman provided, the alpha values are in general lower.
#
# ### Clustering Coefficient:
# When analyzing clustering coefficients in the given data and my own values, each type of network has different clustering coefficients due to society's emphasis on groupings and communities, which is the most valid explanation for the large range of probabilities.
#
#
# ### Assortative Mixing:
# In general, all real networks are expected to have negative assortativity by degree values except for social networks. For instance, Biological networks (metabolic and protein networks) and Information (WWW) networks have negative assotativity. However, social networks are expected to have a positive assortativity by degree value, and the Collaboration and Phone Call networks fulfil this expectation with high positive values.

# %% [markdown]
# ## Q3.
#
# **A. (2 pts)** A particular network is believed to have a degree distribution that follows a power law for nodes of degree 10 or greater. Among a random sample of nodes in the network, the degrees of the first 20 nodes with degree 10 or greater are:
#
# 16, 17, 10, 26, 13, 14, 28, 45, 10, 12, 12, 10, 136, 16, 25, 36, 12, 14, 22, 10
#
# Calculate (by hand) the exponent $\alpha$ of the power law using the equation provided in the lecture.
#
# **B. (1 pt)** One of the networks below is approximately scale-free; the other is not. Which is which and how can you tell?
#
# **C. (1 pt)** For a scale free network with $\alpha=2.1$ approximately what fraction of the highest-degree nodes have a 80\% of all the edge-ends? ***Hint:*** You can obtain this approximately from the lorenz curves for the scale free networks provided in the lecture. You can also calculate it using the formula $W=P^{(\alpha-2)/(\alpha-1)}$ where $W$ is the fraction of ends of edges attached to the fraction $P$ of highest degree nodes.
#
# ![Screen Shot 2022-10-12 at 3.32.29 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## A3.
#
# ANSWER (TEXT):
#
# A. A correct answer from your friend:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B. The network on the right represents an approximately scale-free degree distribution. As we can tell, the cumulative distribution is approximately astraight line on the logarithmic scales used in the figure.

# %% [markdown]
# C.
# Rearrange the formula given for P gives P = $W^{(a-1)/(a-2)}$
#
# Set W = 0.8 and a = 2.1 gives P = 0.084.
# This measure indicates that approximately 8.4% of highest degree nodes have 80% of all the edge ends.

# %% [markdown]
# ## Q4. (3 pts)
#
# Follow the steps provided in the Gephi Handout to create the small friends network below.
#
# ***A.*** Create the "friends_nodes.csv" and "friends_edges.csv" tables in Excel or Google Sheets. Then import the files to Gephi following the instructions.
#
# ***B.*** View the network in Overview. And create a visually appealing plot of your network. Your network should
#
# - show the labels
# - not have overlapping labels
# - has appropriate sizes for the labels
# - has appropriate node size and edge thickness
#
# Provide a screenshot of your network plot. Please note that your network plot does not have to be the same with what is given here.
#
# ![eyJidWNrZXQiOiJhc3NldHMucHVicHViLm9yZyIsImtleSI6ImVtcmV4cmU4LzQxNTg3NzYzMTMxOTUzLnBuZyIsImVkaXRzIjp7InJlc2l6ZSI6eyJ3aWR0aCI6ODAwLCJmaXQiOiJpbnNpZGUiLCJ3aXRob3V0RW5sYXJnZW1lbnQiOnRydWV9fX0=.png](data:image/png;base64,...)

# %% [markdown]
# ## A4.
#
# ANSWER (TEXT):
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Q5. (2 pts)
#
# We will analyze a social network of characters in Star Wars movie.
#
# ***A.*** Look at the 2 .CSV files provided. Explain what each node, edge represents. What is the type of this network?
#
# ***B.*** Following the steps in the Gephi Handout, create a plot of this network. Choose a layout and apply on this network. Explain your layout of choice. You should also do final touches in the plot before exporting to make it look professional.
#
# Please export your plot as a PNG or PDF file, and copy/paste it to your answer.
#
# **Note:** You can try different layout and plotting options to find a setting that will make your plot visually appealing. You are expected to provide a professional looking plot here.

# %% [markdown]
# ## A5.
#
# ANSWER (TEXT):
#
# A.	In the Star Wars social network, each node represents a Star Wars character. Each node has a “Scene” attribute. This attribute distinguishes the characters based on how many scenes they have been in. A link connects two characters if they appeared in a scene together, and the weight of each link represents the number of scenes they appeatd together.
#
# B. For example: Yifan Hu layout. This layout represents how important each character is and the characters' connections/relationships to each other. The Yifan Hu layout is used to place emphasis on complementaries, placing those who are more connected closer together, and those who are less connected and central farther apart.
#
#
# ![Screen Shot 2022-10-30 at 11.44.32.png](data:image/png;base64,...)

# %% [markdown]
# ## Q6. (4 pts)
#
# We will continue to visualize the Star Wars network here.
#
# **Note:** You can try different layout and plotting options to find a setting that will make your plot visually appealing. You are expected to provide a professional looking plot here.
#
# ***A.*** Compute the Average Weighted Degree, Closeness Centrality, and Average Path Length. Take a screenshot of the Closeness Centrality distribution. ***Note:*** In the "Statistics" Panel, when you run the "Network Diameter", it computes some of the centrality measures for each node, and they can be seen in the "Data Laboratory" view in Gephi.
#
# ***B.*** In your previous plot, (Please copy/paste the screenshots to your answer.)
#
# i. Adjust edge thickness to reflect the weight. Size the nodes in the network based on Degree. (Set min size to 1, max size to 50). Resize the labels to reflect their node's size. Take a screenshot of the network after this step.
#
# ii. Following the Handout, color the nodes based on Betweenness Centrality. Take a screenshot of the network after this step.
#
# iii. Following the Handout, filter the network so that it becomes a 6-core. Export the final Star Wars network as PNG or PDF file, and copy/paste it to your answer.

# %% [markdown]
# ## A6.
#
# ANSWER (TEXT):
#
# A. Screenshot of the Closeness Centrality Distribution:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# B.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ii.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# iii.
#
# ![image.png](data:image/png;base64,...)
