# %% [markdown]
# # ACTIVE LEARNING EXERCISE 3
# ## Networks: Friends, Terrorists, and Epidemics
# ## Due by 11:55pm on Friday, September 23, 2022
#
# ### Name:
# ### Group Member(s):
#
# ## GUIDELINES
# - You may either type or write out your responses. You should provide your own solutions for the questions. For the assignment you can use resources available to you (e.g., textbook, notes, your classmates, tutor, and Prof. Ay.)
# - To receive full credit, you must show all of your work and adhere to the formatting guidelines outlined here. Please keep in mind that some of the questions may be graded based on their completion.
# - Please write your name on your assignment. Submit the answers to questions electronically in one or more documents by uploading a PDF or set of images to Gradescope. If you submit a pdf file, please select each question and then click on the page(s) for that question. Instructions for submitting your work can be found in the posted video (https://www.youtube.com/watch?v=u-pK4GzpId0).
# - You are welcome to use Python to perform calculations or check your work. Just be sure to include any equations and Python code that you used.
# - You can use https://colab.research.google.com/ website to work on this notebook. After finishing your work you can download the notebook.
# - You can use a resource such as https://www.vertopal.com/en/convert/ipynb-to-pdf to convert your Python notebook to a pdf file.
# - You can use a resource such as https://combinepdf.com/ website to combine pdf files. For example if you want to combine your handwritten solutions with your answers that you created through a computer.
# - For the non-coding questions in this assignment, you may enter your responses beneath the question, or write your answers in a Word document and convert it to a pdf file, or write your answers by hand on a piece of paper, photograph it, and convert it to a pdf file.

# %% [markdown]
# ##Q1. (8 pts)
#
# **A.** Please read The Second Link: The Random Universe chapter of the Linked book by Barabasi, and answer the following questions. (Approximate Length: One Page)
#
# i. What are the chapter's main points? Use examples from the book to explain it.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Which, if any, remaining questions do you have about random networks? Justify why.
#
# **B.** Please read The Third Link: Six Degrees of Separation chapter of the Linked book by Barabasi, and answer the following questions. (Approximate Length: One Page)
#
# i. What are the chapter's main points? Use examples from the book to explain it.
#
# ii. Provide a quote (or passage) that stood out to you particularly. Justify why.
#
# iii. Which, if any, remaining questions do you have about six degrees of freedom? Justify why.

# %% [markdown]
# ## A1.
#
# ANSWER (TEXT):
#
# ***SECOND LINK***
#
# ***A VERY GOOD ANSWER FROM ONE OF YOUR FRIENDS***
#
# A.i.
# The random universe is divided into 9 sub-chapters, and the first one begins by
#  describing the last moments of Leonhard Euler on September 18, 1783, making
#  some mathematical calculations, and how later that day, he suffered a brain
# hemorrhage and passed away. One of the most impressive and remarkable aspects
#  of Euler’s career is how he developed a large display of papers even though he was
#  almost completely blind. One of his most famous projects offered rigorous
# mathematical proof to solve the Konigsberg Bridges problem, starting an immense
#  branch of mathematics known as graph theory. Euler’s great insights lay in viewing
#  Konigsberg bridges as graphs, a collection of nodes connected by links. He proved
# that there is no path crossing all seven bridges only once because such a path cannot
#  exist in a graph that has more than two nodes with an odd number of links. Overall,
#  graph theory boomed after Euler’s contribution. After Euler, two centuries passed
#  before mathematicians started asking the question, ‘how do real networks form?”
#  which the first answers came only in the 1950s.
#
# Subchapter two starts by describing a seventeen-year-old Hungarian boy in the
#  1920s and narrates his impressive mathematical skills. This boy was Paul Erdos,
#  who wrote over 1,500 mathematical papers, and along with Alfred Renyi, laid the
#  foundation of the theory of random networks.
#
# The third subchapter describes a hypothetical party for a hundred guests and how
#  the guests will be increasingly interwoven by intangible links, sharing information,
#  and connections with each other. Then it poses the question that if the reputation of
#  a rare fine port wine (which was only revealed to one person) would reach all of the
#  guests before the end of the party. According to Renyi and Erdos, if each person gets
#  to know at least one other guest, then soon everybody will be drinking the fine wine.
#  The guests at the party represent a part of a problem in graph theory which was
#  pioneered by Euler. Renyi and Erdos came up with the simplest solution to connect
# the nodes randomly; therefore, viewing graphs and the world as fundamentally
#  random.
#
# Subchapter 5 goes back to the cocktail party example for further examination,
#  describing the formation of a unique giant cluster, which mathematicians call “the
#  emergence of a giant component” and sociologists would call a community. Laszlo
#  claims that regardless of the terminology used in each discipline, one cannot deny
#  that something special happens after many nodes are connected to each other.
#
# Subchapter 6 describes how each of us is part of this worldwide social net. Laszlo
#  claims there is always a path between one component to the other and that nothing
#  is excluded from this highly interconnected web of life and that it only takes one link
# to stay connected to the whole. It emphasizes the idea that nothing can escape from
#  very dense networks and every node is navigable.
#
# Subchapter 7 begins by describing Erdos and Renyi's remarkable discovery of the
#  emergence of giant clusters in graph theory and how it only takes one link to form a
# society. They were also humbled by real graphs' level of complexity, so assumed
#  their randomness. The chapter also follows by narrating the random yet intriguing
#  stories behind how Renyi started working as colleagues with Erdos.
#
# Subchapter 8 begins by describing that the Amsterdam meeting of Erdos and Renyi
#  marked the beginning of a close friendship and scholarly collaboration. Then the
#  author builds a bit more into their work and in random graph theory claiming that “
#  if the network is large, despite the links’ completely random placement, almost all
#  nodes will have approximately the same number of links.” Moreover, for the random
#  networks model of Renyi and Erdos, the histogram was proved by Bela Bolobas,
#  showing that the histogram can be explained through Poisson distribution,
#  indicating that the majority of the nodes have the same number of links as the
#  average node does. Therefore predicting that if we assign all social links as random,
# we end up with a highly democratic society where all of us are average, and only a
#  few deviate from the norm.
#
# Subchapter 9 briefly summarizes Erdos and Renyi's work by saying that they
#  equated complexity with randomness. However, Laszlo criticizes their work by
#  utilizing rhetorical questions and posing the statement that most of us feel we do
# not live in such a random world and that there has to be some order behind these
#  complex systems. Still, their great contributions were motivated by a deep curiosity
#  about the mathematical depths rather than by their applications.
#
# A. ii.
#  “ Graphs or networks have properties, hidden in their construction, that limit or
#  enhance our ability to do things with them” (page 12). This statement made by Euler
#  truly caught my attention. He was a pioneer in the study of networks yet places the
#  foundations for many mathematicians working in this field over the years, including
#  Renyi and Erdos. Describing networks as structures with hidden properties
#  emphasizes the idea behind their enormous complexity, which leads the path for
# Renyi and Erdos to study and examine them through the lens of randomness. I
#  myself, as a beginner in the study of networks, find myself fascinated and intrigued
#  by the depths of its complexity. However, as we have been, little by little,
# understanding and breaking down some small pieces of the whole, I have been able
#  to enhance my abilities on the utilities of networks in my personal life and
#  experiences.
#
# A. iii.
# I was intrigued by a quote presented in this chapter that summarized Renyi and
#  Erdos's main ideas on random networks as “God enjoys playing dice,” next to a
#  statement made by Einstein that said, “God does not play dice with the universe.” I
# am not a religious person myself, but I believe that there must be some order and
#  significance behind the incredible complexity of the web of life in the universe, and I
#  wonder, what do real networks look like? and what is the significance and structure
#  behind the creation of all the complex networks in the universe? I would be excited
#  to read more about this type of discussion from a scientific and spiritual perspective.
#
# ***ANOTHER GOOD ANSWER FROM ONE OF YOUR FRIENDS***
#
# The Second Link: The Random Universe chapter of the Linked book by Barabasi
# discusses Random Networks and how they help us understand the randomness in our
# world. The chapter begins by discussing Euler’s investigation of the Konigsberg
# Bridges. The Konigsberg bridges are a set of 7 bridges to help connect the elegant
# island Kneiphof with other parts of the city. Though looking at the bridges as links and
# the pieces of land as nodes, Euler was able to write the proof that proved no path will
# cross all seven bridges only once. From Euler’s proof, we began to look at problems of
# these sorts as graphs with different properties, and understand them through structure,
# construction, and formulas.
# The chapter then continued to propose a scenario where a cocktail party was
# hosted for 100 guests who didn't know one another beforehand. As the party goes on
# the guests then meet with one another and create friendship links. The question of if
# you tell one guest about an expensive wine being served at the party, how long before
# everyone knows? Erdos and Renyi proposed that it would only take 30 minutes for all
# the guests to know about the wine because of how quickly these invisible social circles
# form.
# Overall Erdos and Renyi proposed that graphs are fundamentally random, and
# therefore so is our world. In the world, everyone and everything is interconnected,
# because it only takes one link for someone/something to stay connected. Random
# graph theory, developed by Erdos, states that in a random graph - each link is randomly
# distributed to nodes - all nodes will still have approximately the same number of links.
# Therefore as a whole in society, if social links are distributed randomly, we will all have a
# very average number of links/friends, and it will be very uncommon to deviate from the
# norm number of friends.
#
# A passage that stood out to me was “Therefore, random graph theory predicts
# that if we assign social links randomly, we end up with an extremely democratic society,
# where all of us are average and very few deviate from the norm to be extremely social
# or utterly asocial types. We obtain a network with a very uniform fabric in which the
# mean is the norm” (26). I found this passage interesting because it points out that
# randomness can lead to uniformity - seemingly opposites. This makes it relatively
# simple to predict how many social links will occur in a network. I think of my friends, and
# how many people I am friends with as my choice, but in the scheme of things, it could
# easily be predicted based on the entirety of a social network and the number of nodes in
# the network.
#
# I still have questions about the differences between random networks and
# non-random networks. How much of our bodies metabolism and interconnectivity is
# random? There must be parts that are not random given our ability to survive but to a
# certain extent. I do think there is some randomness behind the effectiveness of the
# networks in our bodies.
#
# ***THIRD LINK***
#
# ***A VERY GOOD ANSWER FROM ONE OF YOUR FRIENDS***
#
#
# B.	i) Six Degrees of Separation chapter
# The chapter ‘The third link’ is divided into 6 subchapters and begins by describing how there was increased excitement and chaos in Budapest because of the release of a collection of poems written by Frigyes Karinthy, titled ‘ Igy irtok ti,’ one of the most read books in Hungarian history, which gained him enormous popularity. In 1929, Karinthy published his 46th book, which turned out to be a critical failure. However, Laszlo revives one of Karinthy’s stories, titled “Chains,” revealing the insight that people around the world are linked by at most five links, the concept we know today as “six degrees of separation”
#
# The first sub-section describes how the concept of “six degrees of separation” was rediscovered by Stanley Milgram in 1967 and how the structure of social networks soon became a highly debated topic among scholars at MIT and Harvard. The question driving his experiment was, “how many acquaintances would it take to connect two randomly selected individuals? He picked Wichita, Kansas, and Omaha, Nebraska as his starting points, and he sent letters to randomly chosen residents. He had a pressing concern if the letters would make it to the final targets. He found out the median number of intermediate persons was 5.5, what we know as the “six degrees of separation” - a title that originated after a play on Broadway. Even though the study was only focused on the US, John Guare popularized the term, and the myth behind this idea became applicable to the whole world. The idea that a network of six billion nodes in which any pair of nodes are on average six links from each other. The subchapter ends by posing the question if the six degrees is a concept only applicable to humans or if it is also applicable to other kinds of networks.
#
# The second subchapter describes Tim Berners-Lee's dream of linking the information of computers everywhere, which turned into the World Wide Web, one of the largest ever human-made networks. Lee Giles and Steve Lawrence took upon the task of measuring the size of the whole web. Their measurements in 1999 indicated that the Web had close to a billion documents, growing much faster than human society. The author emphasizes the idea that, unlike our current society, the
#
# web is digital, meaning that software such as a robot or crawler could return a complete map of the web. He later started research with Jeong and Reka Albert to pursue a similar but more modest task in which they mapped the nd.edu domain. Their results indicated that there are eleven clicks away from each other between web documents. However, their domain only represented a tiny fraction of the whole world wide web. Since their computers did not have the capacity to study the world wide web in its entirety, they decided to break down their study into components. The results indicated that the average separation between the nodes increased much more slowly than the number of documents. In the end, they determined that any document is, on average, only nineteen clicks away from any other.
#
# Subchapter 3 describes subsequent discoveries revealing short-degree separations in every other network scientists have had the chance to study, from food webs to molecules and their chemical reactions, showing an average between 2 - 14 degrees of separation. The question that arises is how networks achieve such a short path despite their billions of nodes. The author explains that the origin of the small separation is a logarithmic term. The logarithm shrinks the large networks, creating the small world around us.
#
# Subchapter 4 remarks on the idea that the earliest written account Laszlo knows about the six degrees of separation comes from Karinthy - the Hungarian writer. He also discusses the possibility Erdos and Renyi heard from this idea by reading Karinthy’s publication. Laszlo skillfully continues tying different links between these scientists, and he ultimately mentions Milgram and the fact that he had a Hungarian father, adhering to the possibility of having overheard the idea of Karynthy’s five degrees of separation as he was growing up.
#
# Subchapter 5 begins with the statement that the six/nineteen degrees phrase is deeply misleading because it suggests that things are easy to find in a small world, which is far from the truth. Laszlo points out that there is an enormous number of paths with widely different lengths between any two people and that through Milgrams’s experiment, the real separation in society was clearly overestimated. As we don't have a social search engine, we may never know the actual number with total certainty.
#
# The last subchapter emphasizes the idea that six degrees in the product of our modern society and due to our newfound ability to communicate over great distances. In the past, people would often easily lose contact with their relatives if they were to move to another country. However, things have rapidly changed in the last decades with the mail system and the telephone. The world is shrinking because social links are kept alive and can be easily activated, bringing down the degrees of separation. Today, our ability to reach people has less and less to do with the physical distance between us.
#
# B. ii)
#
# “Everybody on this planet is separated by only six other people. Six degrees of separation” Between us and everybody else on this planet. The president of the United States. A gondolier in Venice… It’s not just the big names. It’s anyone” (page
#  29). This quote was taken from a play on Broadway that originated the brilliant term “six degrees of separation.” However, I also relate it closely to my own life, and it makes me wonder about the accuracy behind this idea. As an international student coming from Chile, I am genuinely intrigued by how people in different parts of the world can be connected to each other in one way or another. It makes me reflect on the friendships that I already have and how each individual can act as a node to form links between people. I remember having a discussion around this concept with some friends some years ago, but I never knew where the study and reasoning came from until today.
#
# B. iii)
#
# I am curious about studies on the “six-degrees of separation” from an intersectional perspective (e.g. race, gender, and socio-economic status), and how considered ‘more privileged people’, secure easier access, less degrees of separation to others vs BIPOC (black, indigenous, people of color). We observe inequalities expressed through different spheres of human life, so I wonder how this idea has been examined in networks theory.
#
# ***A GOOD ANSWER FROM ONE OF YOUR FRIENDS***
#
# The Third Link: Six Degrees of Separation chapter of the Linked book by
# Barabasi discusses degrees of separation in networks, particularly in social networks
# and the web network. Karinthy first wrote about the concept of six degrees of separation
# in 1929 and wrote that the degree of separation between everyone on earth was at
# most five acquaintances. Then, in 1967, the Six-degree theory was rediscovered by
# Stanley Milgram and tested through an experiment looking at the distance between any
# two people in the United States. He looked at how many acquaintances it would take to
# connect two people.
# Milgram's experiment was to send letters to random remote areas and did so by
# giving a letter to one person and having them send it to a person whom they thought
# would have a better chance of getting the letter to the specified person. Each person
# needed to write their name on the letter to record the number of connections. Milgram
# found there to be a median number of intermediate persons as 5.5, rounded to 6 for 6
# degrees of separation. On earth, there are six billion nodes/people, with an average of
# six links from one another. It’s important to note though that the degrees of separation
# for social networks in the world that Milgram found is much longer than the shortest
# possible, therefore the real separation in society is perhaps much shorter.
# The chapter also looked at the Web to try to find the degree of separation for any
# given page on the Web. It’s incredibly difficult to figure out because there is no map of
# the Web, therefore the author of the book looked at a smaller sample size of the
# distance between any two pages at Notre Dame University. He found that there were
# eleven degrees of separation for the web pages within the university. Given the
# knowledge that the average separation between any two nodes increases slowly as the
# number of pages increases, and looking at small sample sizes, they were able to find
# the Web has an average of 19 degrees of separation.
#
# A passage that particularly stood out to me was about how the internet has
# changed our ability to maintain social links. The six degrees of separation are probably
# much lower because “the number of social links an individual can actively maintain has
# increased dramatically, bringing down the degrees of separation. Milgram estimated six.
# Karinthy five. We could be much closer these days to three” (42). I find it fascinating the
# way the internet has made us even more interconnected by increasing the number of
# people we can stay in contact with. Through social media, it is also so much easier to
# find, and contact people that we think might know someone else, making our links and
# social circles so much more visibly intertwined.
#
# I still have questions about the validity of the six degrees of separation given
# current access to social media and the internet. Looking up a friend on social media and
# looking at their followers could even further decrease the degree of separation. I am
# curious about how much of the six degrees of separation are due to randomness, and
# not knowing who knows who.

# %% [markdown]
# ## Q2. (8 pts)
# ## I. Game of Thrones
#
# Game of Thrones was the hugely popular television series by HBO based on the book series <em>A Song of Ice and Fire</em> by George R.R. Martin. In this question, you will analyze the co-occurrence network of the characters in the  Game of Thrones books. ***Here, two characters are linked if their names appear in the vicinity of 15 words from one another in the books.*** </p>
# <p><img src="https://assets.datacamp.com/production/project_76/img/got_network.jpeg" style="width: 550px"></p>
# <p>The dataset constitutes a network for each book. These networks are given as text files describing the <em>links</em> between characters, with some attributes attached to each link. Let's start by loading in the networks.</p>

# %%
# Make sure you run this code cell to import the relevant libraries and the networks!
import networkx as nx            # Import NetworkX library as nx for its network functions
import numpy as np               # Import NumPy library as np for its mathematical functions
import matplotlib.pyplot as plt  # Import Matplotlib library as plt for its plotting functions
import pandas as pd              # Import Pandas library as pd for its data manipulation and analysis functions

# The following code imports the networks from my Google Drive, and stores them to book1, book2, book3, book4, and book5 variables 
url1 = 'https://drive.google.com/file/d/1kiaWm1GrNlNfhJmQxo6qABTw9n8ddNOk/view?usp=sharing'
path1 = 'https://drive.google.com/uc?export=download&id='+url1.split('/')[-2]
book1 = pd.read_csv(path1)

url2 = 'https://drive.google.com/file/d/1LvkDY0xqBDyOF5CfbKe7EdkBogrSJmPe/view?usp=sharing'
path2 = 'https://drive.google.com/uc?export=download&id='+url2.split('/')[-2]
book2 = pd.read_csv(path2)

url3 = 'https://drive.google.com/file/d/17SXpzvjdJngtJYe5bD30YON6voN1NPvl/view?usp=sharing'
path3 = 'https://drive.google.com/uc?export=download&id='+url3.split('/')[-2]
book3 = pd.read_csv(path3)

url4 = 'https://drive.google.com/file/d/1Ygk0ORmfyNewepj41ErQRRzJp5TLvOdc/view?usp=sharing'
path4 = 'https://drive.google.com/uc?export=download&id='+url4.split('/')[-2]
book4 = pd.read_csv(path4)

url5 = 'https://drive.google.com/file/d/1QaDI3jhisxnQdMkj5QmCAxyrFgr-leHV/view?usp=sharing'
path5 = 'https://drive.google.com/uc?export=download&id='+url5.split('/')[-2]
book5 = pd.read_csv(path5)

# %% [markdown]
# ## II. Network of Thrones
# <p>The resulting DataFrames, for <code>book1</code> for example, has 5 columns: <code>Source</code>, <code>Target</code>, <code>Type</code>, <code>weight</code>, and <code>book</code>. Source and target are the two nodes that are linked. A network can have directed or undirected links and in this network all the links are undirected. The weight attribute of every link tells us the number of interactions that the characters have had over the book, and the book column tells us the book number.</p>
# <p>Once we have the data loaded as a pandas DataFrame, it's time to create a network. We will use <code>Networkx</code> to create a network object for each book.</p>

# %%
# Create a network object for each book. 
G_book1 = nx.Graph() 
G_book2 = nx.Graph()
G_book3 = nx.Graph()
G_book4 = nx.Graph()
G_book5 = nx.Graph()

# Currently, the network objects G_book1,..., G_book5 are empty. 
# Let's now populate it with the links from book1,..., book5. 
for _, edge in book1.iterrows():
    G_book1.add_edge(edge['Source'], edge['Target'], weight=edge['weight'])

for _, edge in book2.iterrows():
    G_book2.add_edge(edge['Source'], edge['Target'], weight=edge['weight'])

for _, edge in book3.iterrows():
    G_book3.add_edge(edge['Source'], edge['Target'], weight=edge['weight'])

for _, edge in book4.iterrows():
    G_book4.add_edge(edge['Source'], edge['Target'], weight=edge['weight'])

for _, edge in book5.iterrows():
    G_book5.add_edge(edge['Source'], edge['Target'], weight=edge['weight'])

# Creating a list of networks for all the books
books = [G_book1]
books.append(G_book2)
books.append(G_book3)
books.append(G_book4)
books.append(G_book5)

# %% [markdown]
# ## A. Who is the most important character based on different centrality measures in the fifth book of Game of Thrones?
# <p>Is it Ned Stark, Jon Snow, Tyrion, Daenerys, or someone else? Network analysis offers us many different metrics to measure the importance of a node in a network. Note that there is no "correct" way of calculating the most important node in a network, every metric has a different meaning.</p>
#
# Extract the top ten important characters (**in the case of ties you can take more than ten characters**) from the fifth book using four different centrality metrics.
#
# i. Degree centrality.
#
# ii. Closeness Centrality
#
# iii. Betweenness Centrality
#
# iv. PageRank Centrality
#
# ***Note:*** You could create a four by ten table from this analysis. Using this table please answer the following questions:
#
# ***Who is the most important character based on degree centrality? closeness centrality? betweenness centrality? Pagerank centrality? Please interpret your findings. For example you can say "Based on degreee centrality X character is the most important character in the fifth book. This indicates that X character ..."***
#
# ***In your optinion, who is the most important character in the fifth book (based on all metrics combined)? Please provide a justification for your answer.***

# %%
# ANSWER (CODE):
def my_weighted_degree_centrality(WG):   # Weighted degree centrality function
  my_dict= dict(WG.degree(weight='weight'))
  total = sum(my_dict.values())
  result = {key: value / total for key, value in my_dict.items()}
  return result

d_centralities = my_weighted_degree_centrality(G_book5)             # Find the degree centrality of all characters in book 5
# A code piece that might help you to sort the centralities
print('Sorted Degree Centrality Scores:', dict(sorted(d_centralities.items(), key=lambda item: item[1], reverse=True)[0:10]))

c_centralities=nx.closeness_centrality(G_book5, distance='weight')  # Find the closeness centrality of all characters in book 5
# A code piece that might help you to sort the centralities
print('Sorted Closeness Centrality Scores:', dict(sorted(c_centralities.items(), key=lambda item: item[1], reverse=True)[0:10]))

# Please write a similar code for the other centrality metrics
# Out:
# Sorted Degree Centrality Scores: {'Jon-Snow': 0.06664915046417937, 'Daenerys-Targaryen': 0.06314590996671922, 'Tyrion-Lannister': 0.03976177964617271, 'Stannis-Baratheon': 0.03678402522333158, 'Theon-Greyjoy': 0.026887370818006656, 'Hizdahr-zo-Loraq': 0.0255736556314591, 'Barristan-Selmy': 0.023646873357856018, 'Quentyn-Martell': 0.02023121387283237, 'Ramsay-Snow': 0.016202487300753198, 'Jon-Connington': 0.014801191101769137}
# Sorted Closeness Centrality Scores: {'Stannis-Baratheon': 0.09175377468060394, 'Robert-Baratheon': 0.08722053546784433, 'Tywin-Lannister': 0.08517520215633423, 'Tyrion-Lannister': 0.08342133051742344, 'Cersei-Lannister': 0.0833553152202585, 'Daenerys-Targaryen': 0.08239895697522816, 'Asha-Greyjoy': 0.08036622583926754, 'Myrcella-Baratheon': 0.07987866531850354, 'Axell-Florent': 0.07880299251870324, 'Doran-Martell': 0.07864609258337481}

# %%
b_centralities = nx.betweenness_centrality(G_book5, weight='weight')             # Find the harmonic centrality of all characters in book 5
# A code piece that might help you to sort the centralities
print('Sorted Betweenness Centrality Scores:', dict(sorted(b_centralities.items(), key=lambda item: item[1], reverse=True)[0:10]))

p_centralities = nx.pagerank(G_book5, weight='weight',max_iter=100000)  # Find the closeness centrality of all characters in book 5
# A code piece that might help you to sort the centralities

print('Sorted PageRank Centrality Scores:', dict(sorted(p_centralities.items(), key=lambda item: item[1], reverse=True)[0:10]))
# Out:
# Sorted Betweenness Centrality Scores: {'Stannis-Baratheon': 0.36406677465146403, 'Daenerys-Targaryen': 0.25381750424245914, 'Jon-Snow': 0.20565214271362542, 'Robert-Baratheon': 0.20012876291658696, 'Asha-Greyjoy': 0.1739937522125587, 'Tyrion-Lannister': 0.15869758899596131, 'Cersei-Lannister': 0.14384539416335676, 'Godry-Farring': 0.1043978491537262, 'Tywin-Lannister': 0.09652381909163119, 'Barristan-Selmy': 0.08378527808003416}
# Sorted PageRank Centrality Scores: {'Jon-Snow': 0.05957228608306988, 'Daenerys-Targaryen': 0.04429235448886177, 'Stannis-Baratheon': 0.03481869037148472, 'Tyrion-Lannister': 0.028882459103007546, 'Theon-Greyjoy': 0.025040537107443268, 'Hizdahr-zo-Loraq': 0.016475795289845357, 'Cersei-Lannister': 0.015888378840130987, 'Barristan-Selmy': 0.015527100181872743, 'Ramsay-Snow': 0.014337111663951341, 'Quentyn-Martell': 0.014036603547212612}

# %% [markdown]
# ### ANSWER (TEXT):
# i. Degree Centrality:
#
# Jon Snow is the most important character in the fifth book in terms of degree centrality. This indicates that Jon Snow has the highest number of 'one hop' links/connections with other characters, and therefore shows he is very popular and influential in the books.
#
# ii. Closeness Centrality:
#
# Stannis Baratheon is the most important character in the fifth book based on closeness centrality. Due to his proximity to other characters, Stannis-Baratheon can convey information and influence them the fastest.
#
# iii. Betweenness Centrality:
#
# Stannis-Baratheon is the most important character in the fifth book based on betweenness centrality. This indicates that Stannis Baratheon is a "bridge" between other characters in the book and has the highest count of other characters needing to go through him to contact another character.
#
# iv. PageRank Centrality:
#
# In terms of PageRank centrality, Jon Snow is the most important character. His high PageRank centrality suggests that this character is the most important in the network based not only on the number of connections he has, but also on the importance of the characters he is connected to.

# %% [markdown]
# Now lets look at the overall who is the most important character.

# %%
# THIS CODE CREATES A DATA FRAME FROM TOP 10 IN EACH CENTRALITY METRIC. BELOW, I USE IT TO SEE THE RANK OF EACH CHARACTER.
# YOU DO NOT NEED TO WRITE THIS CODE. YOU CAN JUST CREATE A TABLE BY HAND THAT SHOWS EACH CHARACTER'S RANK AND USE IT FOR YOUR ANALYSIS.
d_centralities2=dict(sorted(d_centralities.items(), key=lambda item: item[1], reverse=True)[0:10])
c_centralities2=dict(sorted(c_centralities.items(), key=lambda item: item[1], reverse=True)[0:10])
b_centralities2=dict(sorted(b_centralities.items(), key=lambda item: item[1], reverse=True)[0:10])
p_centralities2=dict(sorted(p_centralities.items(), key=lambda item: item[1], reverse=True)[0:10])
centralities = pd.DataFrame({'degree centrality':d_centralities2,'betweenness centrality': b_centralities2, 'closeness centrality':c_centralities2, 'pagerank': p_centralities2})

# %%
centralities_ordered_by_degree=centralities.sort_values(by=['degree centrality'],ascending=False)
centralities_ordered_by_degree["degree centrality"]
# Out:
# Jon-Snow              0.066649
# Daenerys-Targaryen    0.063146
# Tyrion-Lannister      0.039762
# Stannis-Baratheon     0.036784
# Theon-Greyjoy         0.026887
# Hizdahr-zo-Loraq      0.025574
# Barristan-Selmy       0.023647
# Quentyn-Martell       0.020231
# Ramsay-Snow           0.016202
# Jon-Connington        0.014801
# Robert-Baratheon           NaN
# Asha-Greyjoy               NaN
# Cersei-Lannister           NaN
# Godry-Farring              NaN
# Tywin-Lannister            NaN
# Myrcella-Baratheon         NaN
# Axell-Florent              NaN
# Doran-Martell              NaN
# Name: degree centrality, dtype: float64

# %%
centralities_ordered_by_betweenness=centralities.sort_values(by=['betweenness centrality'],ascending=False)
centralities_ordered_by_betweenness["betweenness centrality"]
# Out:
# Stannis-Baratheon     0.364067
# Daenerys-Targaryen    0.253818
# Jon-Snow              0.205652
# Robert-Baratheon      0.200129
# Asha-Greyjoy          0.173994
# Tyrion-Lannister      0.158698
# Cersei-Lannister      0.143845
# Godry-Farring         0.104398
# Tywin-Lannister       0.096524
# Barristan-Selmy       0.083785
# Theon-Greyjoy              NaN
# Hizdahr-zo-Loraq           NaN
# Quentyn-Martell            NaN
# Ramsay-Snow                NaN
# Jon-Connington             NaN
# Myrcella-Baratheon         NaN
# Axell-Florent              NaN
# Doran-Martell              NaN
# Name: betweenness centrality, dtype: float64

# %%
centralities_ordered_by_closeness=centralities.sort_values(by=['closeness centrality'],ascending=False)
centralities_ordered_by_closeness["closeness centrality"]
# Out:
# Stannis-Baratheon     0.091754
# Robert-Baratheon      0.087221
# Tywin-Lannister       0.085175
# Tyrion-Lannister      0.083421
# Cersei-Lannister      0.083355
# Daenerys-Targaryen    0.082399
# Asha-Greyjoy          0.080366
# Myrcella-Baratheon    0.079879
# Axell-Florent         0.078803
# Doran-Martell         0.078646
# Jon-Snow                   NaN
# Theon-Greyjoy              NaN
# Hizdahr-zo-Loraq           NaN
# Barristan-Selmy            NaN
# Quentyn-Martell            NaN
# Ramsay-Snow                NaN
# Jon-Connington             NaN
# Godry-Farring              NaN
# Name: closeness centrality, dtype: float64

# %%
centralities_ordered_by_pagerank=centralities.sort_values(by=['pagerank'],ascending=False)
centralities_ordered_by_pagerank["pagerank"]
# Out:
# Jon-Snow              0.059572
# Daenerys-Targaryen    0.044292
# Stannis-Baratheon     0.034819
# Tyrion-Lannister      0.028882
# Theon-Greyjoy         0.025041
# Hizdahr-zo-Loraq      0.016476
# Cersei-Lannister      0.015888
# Barristan-Selmy       0.015527
# Ramsay-Snow           0.014337
# Quentyn-Martell       0.014037
# Jon-Connington             NaN
# Robert-Baratheon           NaN
# Asha-Greyjoy               NaN
# Godry-Farring              NaN
# Tywin-Lannister            NaN
# Myrcella-Baratheon         NaN
# Axell-Florent              NaN
# Doran-Martell              NaN
# Name: pagerank, dtype: float64

# %% [markdown]
# We create a table for each of the following centrality metrics to estimate the overall importance of each character in Book 5.
#
# Based on four centrality metrics, there are four key characters.
#
# Jon Snow (Degree Centrality: 1, Betweenness Centrality: 3, Closeness Centrality:>10, PageRank: 1)
#
# Stannis Baratheon (Degree Centrality: 4, Betweenness Centrality: 1, Closeness Centrality: 1, PageRank: 3)
#
# Daenerys Targaryen (Degree Centrality: 2, Betweenness Centrality: 2, Closeness Centrality: 6, PageRank: 2)
#
# Tyrion Lannister (Degree Centrality: 3, Betweenness Centrality: 6, Closeness Centrality: 4, PageRank: 4)
#
# I will argue that Stannis Baratheon or Jon Snow are the most important characters based on all four metrics. Stannis Baratheon ranks top in both closeness and betweenness centrality, which means he is not only co-mentioned with a large number of individuals, but he also acts as a significant transmitter, involved in several interactions and storylines. Jon Snow scores top in both degree and pagerank centrality, indicating that he is not just well connected but also connected to individuals who are well connected. Because the book series' title is Game of Thrones, I would claim that Jon is closer to assuming the throne and a more important character because he is well linked to well connected people.
#
# OR
#
# In my opinion, the most important character in the fifth book is Stannis Baratheon. Stannis Baratheon has the highest scores for both closeness centrality and betweenness centrality, showing he is the closest character to other characters in the book and people need to go through him to reach other characters. In addition, he has the 4th highest degree centrality
# and the 3rd highest PageRank centrality, showing he has a high number of direct
# connections between other characters and is friends with other people who are popular as well. Although Jon Snow is popular, I think Stannis Baratheon is the most influential due to his closeness and betweenness centrality scores in addition to his high degree centrality and pagerank centrality scores. His ability to spread information and connect with others the quickest makes him the most influential character.

# %% [markdown]
# ## B. The evolution of character importance
#
# According to degree centrality, the most important character in the first book is Eddard Stark but he is not even in the top 10 of the fifth book. The importance of characters changes over the course of five books because, you know, stuff happens... :)
#
# Look at the evolution of centrality measures of a few important characters like ['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow', 'Daenerys-Targaryen', 'Cersei-Lannister', 'Stannis-Baratheon', 'Sansa-Stark'] from first book to the fifth book. I am providing code for a few of the centrality metrics here. Please write a similar code for the other centrality metrics mentioned above.
#
# ***In your opinion how does the importance of these seven characters change from the first book to the fifth book. Your answer should take into account all centrality measures.***
#
# ***Note:*** Some characters might show ***NaN*** for some of the books. You may ignore those data points in your analysis.
#
# ***In your optinion, who is the most important character (out of the seven characters we analyze here) overall (based on all metrics combined) in the Game of Thrones books? Please provide a justification for your answer.***

# %%
def my_weighted_degree_centrality(WG):  
  my_dict= dict(WG.degree(weight='weight'))
  total = sum(my_dict.values())
  result = {key: value / total for key, value in my_dict.items()}
  return result

evolution_of_characters = [my_weighted_degree_centrality(book) for book in books]    # Creating a list of degree centrality of all the books
degree_evolution_df = pd.DataFrame.from_records(evolution_of_characters)             # Creating a DataFrame from the list of degree centralities in all the books
# Table for the degree centrality evolution of some characters
print('DEGREE CENTRALITY EVOLUTION:\n', degree_evolution_df[['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow', 'Daenerys-Targaryen', 'Cersei-Lannister', 'Stannis-Baratheon', 'Sansa-Stark']])

evolution_of_characters = [nx.closeness_centrality(book, distance='weight') for book in books] # Creating a list of closeness centrality of all the books
degree_evolution_df = pd.DataFrame.from_records(evolution_of_characters)                       # Creating a DataFrame from the list of closeness centralities in all the books 
# Table for the closeness centrality evolution of some characters
print('CLOSENESS CENTRALITY EVOLUTION:\n', degree_evolution_df[['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow', 'Daenerys-Targaryen', 'Cersei-Lannister', 'Stannis-Baratheon', 'Sansa-Stark']])
# Out:
# DEGREE CENTRALITY EVOLUTION:
#     Eddard-Stark  Tyrion-Lannister  Jon-Snow  Daenerys-Targaryen  \
# 0      0.087157          0.044122  0.053217            0.030071
# 1      0.013286          0.065173  0.028302            0.010692
# 2      0.005544          0.046125  0.044591            0.018167
# 3      0.002862          0.016748  0.010176                 NaN
# 4      0.006569          0.039762  0.066649            0.063146
#
#    Cersei-Lannister  Stannis-Baratheon  Sansa-Stark
# 0          0.028781           0.007127     0.036994
# 1          0.040487           0.036242     0.024607
# 2          0.021411           0.017636     0.031379
# 3          0.082998           0.009540     0.015582
# 4          0.012874           0.036784     0.000876
# CLOSENESS CENTRALITY EVOLUTION:
#     Eddard-Stark  Tyrion-Lannister  Jon-Snow  Daenerys-Targaryen  \
# 0      0.097229          0.100054  0.084277            0.076105
# 1      0.088660          0.084121  0.084341            0.074610
# ...

# %%
# ANSWER (CODE): YOU CAN ADD THE CODE FOR OTHER CENTRALITY METRICS HERE:
evolution_of_characters = [nx.betweenness_centrality(book, weight='weight') for book in books] # Creating a list of betweenness centrality of all the books
degree_evolution_df = pd.DataFrame.from_records(evolution_of_characters)                       # Creating a DataFrame from the list of closeness centralities in all the books 
# Table for the closeness centrality evolution of some characters
print('BETWEENNESS CENTRALITY EVOLUTION:\n', degree_evolution_df[['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow', 'Daenerys-Targaryen', 'Cersei-Lannister', 'Stannis-Baratheon', 'Sansa-Stark']])

evolution_of_characters = [nx.pagerank(book, weight='weight') for book in books] # Creating a list of pagerank centrality of all the books
degree_evolution_df = pd.DataFrame.from_records(evolution_of_characters)                       # Creating a DataFrame from the list of closeness centralities in all the books 
# Table for the closeness centrality evolution of some characters
print('PAGERANK CENTRALITY EVOLUTION:\n', degree_evolution_df[['Eddard-Stark', 'Tyrion-Lannister', 'Jon-Snow', 'Daenerys-Targaryen', 'Cersei-Lannister', 'Stannis-Baratheon', 'Sansa-Stark']])
# Out:
# BETWEENNESS CENTRALITY EVOLUTION:
#     Eddard-Stark  Tyrion-Lannister  Jon-Snow  Daenerys-Targaryen  \
# 0      0.187034          0.153112  0.090277            0.034182
# 1      0.044609          0.098934  0.153331            0.082466
# 2      0.052744          0.107551  0.144756            0.089971
# 3      0.039031          0.167256  0.049077                 NaN
# 4      0.078029          0.158698  0.205652            0.253818
#
#    Cersei-Lannister  Stannis-Baratheon  Sansa-Stark
# 0          0.026219           0.009200     0.055198
# 1          0.048924           0.114470     0.058318
# 2          0.027096           0.141640     0.097710
# 3          0.170725           0.244235     0.157635
# 4          0.143845           0.364067     0.020972
# PAGERANK CENTRALITY EVOLUTION:
#     Eddard-Stark  Tyrion-Lannister  Jon-Snow  Daenerys-Targaryen  \
# 0      0.072362          0.043676  0.047708            0.027099
# 1      0.010619          0.046869  0.028401            0.018024
# ...

# %% [markdown]
# ### ANSWER (TEXT):
# 1. Eddard-Stark: Eddard-Stark is a highly influential character in book one, although his prominence diminishes dramatically during the series. All of his centrality measures fell dramatically with each book, with degree and pagerank centralities in Book 1 being ten times that of Book 5.
#
# 2. Tyrion-Lannister: Over the course of five books, Tyrion-Lannister grew less prominent. His degree, closeness, and pagerank centralities all somewhat dropped. There were minor variations in the measurements provided by each book.
#
# 3. Jon-Snow: In general, Jon-Show is an important character in the series, and he remains so throughout. His closeness and betweeness centrality decreased somewhat, but his betweeness centrality grew tenfold. As the narrative progresses, his role as a transmitter/communicator becomes more important.
#
# 4. Daenerys-Targaryen: This character has a lower degree of importance than the others mentioned above, but she grows more significant during the series, since there was a general rise in all centrality measures, particularly betweenness centrality, which increased 20 times.
#
# 5. Cersei-Lannister: Cersei-Lannister has a lesser degree of importance that remains stable throughout the book, as evidenced by the slight swings by each, but remains reasonably similar by book 5. This character's significance as a bridge between other characters has grown dramatically, which means that, despite only appearing slightly more in the texts, it is on the pathways between pairs of characters.
#
# 6. Stannis-Baratheon: In book one, this figure was considered insignificant due to the small magnitude of his centrality metrics in comparison to others. Nonetheless, this character has experienced the most substantial change in importance, as all of his centrality measures increased significantly by book 5, with degree and pagerank climbing five times and betweennes centrality increasing 35 times.
#
# 7. Sansa-Stark: This character was significant in book one but had declined significantly by book five. All of her centrality indicators declined dramatically, indicating that this character became less essential. Her pagerank and degree centrality fell more than tenfold, showing that she became less influential and less connected to other characters.

# %% [markdown]
# Overall, Jon-Snow is the most important character in the series when all criteria are considered. Not only are his centrality measurements are large in comparison to the others, but he has also grown in importance, becoming more important, connected, and "near" to other characters. His role as a bridge character grew dramatically, which meant he was not just mentioned with other characters, but also connected them. His strong betweenness and closeness centralities indicate that he may influence and converse with other characters quickly and efficiently.

# %% [markdown]
# ***Another good answer from one of your friends***
#
# In my opinion, the importance of Edward-Stark decreased from the first to the fifth book. In all four centrality measures, there was an overall trend of decreasing importance.
#
# Tyrion-Lannister seemed to have relatively consistent importance with a very slight decrease over the evolution of the 4 books. Degree centrality, closeness centrality, and betweenness centrality scores had slight decreases, but the betweenness centrality stayed around the same.
#
# Jon Snow seemed to have an overall slight increase in importance over the course of the 5 books. His degree centrality had a slight increase, his closeness centrality had a slight decrease, his betweenness centrality increased, had his page rank centrality decreased then increased. This shows his popularity increased, but his closeness factor in the network had
# slight decrease.
#
# The importance of Daenerys Targaryen had an overall increase in all four centrality measures, showing an increase in closeness, popularity, and influence.
#
# The importance of Cersei Lannister was consistent for closeness centrality, increased for betweenness centrality, and varied with degree centrality and page rank centrality. This shows her popularity varied over the course of the books but her closeness/role as a bridge was constant/increased over the course of the books.
#
# Stannis Baratheon had varying centrality scores across the books, showing it really depended on the book for how popular/influential he was.
#
# Sansa Stark had decreasing centrality scores for all four measures showing a decreasing influence and popularity over the course of the books.
#
#
# In my opinion, the most important character is Tyrion Lannister in the Game of Thrones books. I believe this because he had the highest average degree centrality and page rank centrality scores over the course of the four books. This means that he was very popular and had links with other characters in most books. He also had fairly consistent high scores in both closeness centrality and betweenness centrality. This shows he had a consistent closeness and maintained his bridges with other nodes throughout the course of the books.

# %% [markdown]
# ### Q3. (1 PT) Find a 3-core in this network if it exists. Show your answer.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A3.
#
# ### ANSWER (TEXT):
# A simple way to find them is to start with a given network and remove from it
# any nodes that have degree less than 3, along with their attached edges, since
# clearly such nodes cannot under any circumstances be members of a 3-core.
# And so we proceed, repeatedly pruning the network to remove nodes with degree less than 3 until no such nodes remain.
#
# We obtain the following 3-core:
# ![Screen Shot 2022-09-18 at 19.59.57.png](data:image/png;base64,...)

# %% [markdown]
# ## Q4. (2 PTS) What is the unnormalized betweenness centrality (formula you are given in the lecture notes) of the central node as a function of number of nodes N? Please show your work.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A4.
#
# ### ANSWER (TEXT):
# Assuming that we have N nodes including the central node there are (N-1)(N-2)/2 paths total and all of them start, end, or pass through the central node. Thus, the betweenness centrality, which is the sum of the fractions of shortest paths the central node lies on, is (N-1)(N-2)/2.

# %% [markdown]
# ## Q5. (2 pts) In this network + and − indicate pairs of people who like each other or don’t, respectively. Is the network structurally balanced and why? Hint: Count the number of negative signs for each loop.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A5.
#
# ### ANSWER (TEXT):
#
# It is balanced, as shown by exhaustively verifying that all loops (of 3 black nodes) contain an even number of minus signs.
#
# Below is a good demonstration from your friend.
#
# ![Screen Shot 2022-09-25 at 20.54.28.png](data:image/png;base64,...)
#
# For instance, the green loop has 3 positive edges and 0 negative edge. The purple loop has 1 positive and 2 negative edges. The orange loop has 1 positive and 2 negative edges.

# %% [markdown]
# ## Q6. (4 PTS) For the following network please calculate by hand the (i) degree, (ii) closeness (iii) harmonic and (iii) betweenness centrality scores for node C.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## A6.
#
# ### ANSWER (TEXT):
# (i). The degree centrality of node C is 2.
#
# (ii). The length of shortest path from C to A: 1, from C to B: 1, from C to D: 2, from C to E: 2.
# Closeness centrality: (5-1)/(1+1+2+2) = 2/3.
#
# (iii). The reciprocal of ength of shortest path from C to A: 1, from C to B: 1, from C to D: 1/2, from C to E: 1/2.
# Harmonic centrality: (1+1+0.5+0.5)/4 = 3/4.
#
# (iv). Betweenness centrality of node C is 0. A correct answer from your friend:
# ![Picture1.png](data:image/png;base64,...)
