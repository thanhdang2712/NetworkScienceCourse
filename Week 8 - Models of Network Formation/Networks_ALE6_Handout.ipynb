# %% [markdown]
# # Networks: Friends, Epidemics & Terrorists
# ## Networks Creation
#
# This ALE Handout shows you different way to collect network data yourself using different softwares or code. The software or code introduced will depend on the type of network created, listed below.

# %%
# Make sure you run this code cell everytime you open the notebook!
import networkx as nx            # Import NetworkX library as nx for its network functions
import numpy as np               # Import NumPy library as np for its mathematical functions
import matplotlib.pyplot as plt  # Import Matplotlib library as plt for its plotting functions
import matplotlib as mplt        # Import Matplotlib library as plt for its plotting functions
import pandas as pd              # Import Pandas library as pd for its data management functions

# %% [markdown]
# ## 1. INTERNET
#
# The code below functions as a web crawler that is designed to mine the links in a Wikipedia article up to a predefined number of hops.
#
# First, you need to run the code block below everytime you open the notebook to install the wikipedia library.

# %%
# !pip install wikipedia
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11695 sha256=222464687983cb670c32281bd41f254c8d7a8e9bf50d1be0223166366f770905
#   Stored in directory: /root/.cache/pip/wheels/15/93/6d/5b2c68b8a64c7a7a04947b4ed6d89fb557dcc6bc27d1d7f3ba
# Successfully built wikipedia
# ...

# %% [markdown]
# ### WEB CRALWER
# The function below is a web crawler that is designed to mine the links in a Wikipedia article up to a predefined number of hops. Every link that you follow from a seed page is a hop. Seed pages are at hop 0, all the pages they point to are at hop 1, etc. Any page that is not reachable within the specified number of hops will not be crawled.
#
# You need to modify the following lines in the code block below to mine the data to your needs:
# - Line 5: The number of hops expected
# - Line 24: The title of the central node (Wikipedia seed page)

# %%
import wikipedia as wk
import pprint

# Constants
DEPTH = 1

def dfs(node, graph, visited, cur_depth):
    # print(node)
    if node not in visited:
        visited.add(node)

        if cur_depth < DEPTH:
            try:
                page = wk.page(node)
                neighbors = page.links
                graph[node] = neighbors

                for n in neighbors:
                    dfs(n, graph, visited, cur_depth + 1)
            except:
                pass

def main():
    start = wk.page(title='Cox-Zucker machine',auto_suggest=False)
    graph = {start.title : start.links}
    
    visited = set()
    dfs(start.title, graph, visited, 0)
    pprint.pprint(graph)


if __name__ == "__main__":
    main()
# Out:
# {'Cox–Zucker machine': ['Algorithm',
#                         'Bibcode (identifier)',
#                         'David A. Cox',
#                         'Doi (identifier)',
#                         'Elliptic surface',
#                         'Geometry',
#                         'ISSN (identifier)',
#                         'Inventiones Mathematicae',
#                         'MR (identifier)',
#                         'Mordell–Weil group',
#                         'Nagoya Mathematical Journal',
#                         'Notices of the American Mathematical Society',
#                         'Princeton University',
#                         'Projective line',
#                         'Rutgers University',
#                         'S2CID (identifier)',
#                         'Steven Zucker',
#                         'Torsion (algebra)',
#                         'Zbl (identifier)']}

# %% [markdown]
# ## 2. SOCIAL NETWORK:
#
# ### YOUTUBE
# We will use (websraper.io), an extension to your Chrome or Firefox browser, to create a network of the youtube recommendation algorithm based on a seed Youtube page.
#
# Let's understand some important tools when scraping website using webscraper:
# (https://webscraper.io/documentation):
#
# - Selectors: Web scraper has multiple selectors that can be used for different type data extraction and for different interaction with the website. The selectors can be divided in three groups:
#   - Data extraction selectors for data extraction.
#   - Link selectors for site navigation.
#   - Element selectors for element selection that separate multiple records
#
# - Data extraction selectors: Data extraction selectors simply return data from the selected element. For example Text selector extracts text from selected element. These selectors can be used as data extraction selectors
# - Link selectors: Link selectors extract URLs from links that can be later opened for data extraction. For example if in a sitemap tree there is a Link selector that has 3 child text selectors then the Web Scraper extract all urls with the Link selector and then open each link and use those child data extraction selectors to extract data. Of course a link selector might have Link selectors as child selectors then these child Link selectors would be used for further page navigation.
# - Element selectors: Element selectors are for element selection that contain multiple data elements. For example an element selector might be used to select a list of items in an e-commerce site. The selector will return each selected element as a parent element to its child selectors. Element selectors child selectors will extract data only within the element that the element selector gave them.

# %% [markdown]
# ### **SCRAPING YOUTUBE RECOMMENDATION SYSTEM**
# To scrape content on Youtube, **follow this detailed guid**e by Professor Martin Hilbert at UC Davis: https://d18ky98rnyall9.cloudfront.net/Bi3XtC9GTTGt17QvRt0xHA_bb0b7ee7e6304930a1e0faff60db632a_UCCSS_Lab_Webscraping.pdf?Expires=1666051200&Signature=GrcbtV20x4a7W5PaQdBw2B38WTLDffJPPrSeAs89Hvdkb4UnkA4wyqCb0voUPYR1mvag58frxb1gd1eFwNwvoe0PSwjkiY7EkFZA~6zq0AjZmGOGG8B1u2nrGzyJwhdPVcoD5dJTq3NXlmCcEpNL7ibAdB0q3r1QAxDedSy2FC0_&Key-Pair-Id=APKAJLTNE6QMUY6HBC5A.

# %% [markdown]
# ##TWITTER/GOOGLE SEARCH TEXT ANALYSIS
# InfraNodus (https://infranodus.com/#about) is a website that combines text analysis and network visualization that can help you analyze the current world-trending topics in real time. This website offers 2 important things that you want to utilize:
# - Real time text input and data import: You can write or import a text, survey responses, PDF files, Google Search web results, **Tweets**,.... as **CSV files**.
# - Network Analysis and Visualization: This tool will represent your data in a beautiful network graph. If you want further analysis, you can always download the network and open in Gephi.
#
# First, take a look at this short Youtube guide (https://www.youtube.com/watch?v=C5WKctvI-PY&ab_channel=NodusLabs).

# %% [markdown]
# ###**WORLD-TRENDING TWEETS/GOOGLE-SEARCH ANALYSIS**
#
# 1. Navigate to the **"Graph"** tab.
# 2. Provided are real-time updated networks, collecting data from live Tweets based-on world-trending hashtags. For instance, there are 'Ukraine-Russia' Google Search, 'Most-Popular Tweets of the day', Google Search on 'Coronavirus', etc.
# ![Screen Shot 2022-10-17 at 16.49.25.png](data:image/png;base64,...)
# 3. Click on one graph you're interested in and navigate to the network visualization.
# - Click on Analytics Icon: Each tab provides you with detailed analysis. For instance, Sentiment analyze if each word is neutral, positive, or negative. The Statistics tab provide overall network metrics.
#
#
# - Click on Setting Icon: This provides you with the option to filter, change node sizes, and Labels.
# 4. To export data: You can export nodes/links data as CSV file, or export the whole network.

# %% [markdown]
# ### \###**SOCIAL MEDIA DATA ANALYSIS WITH NETLYTIC**
# - Netlytic is a cloud-based text and social networks analyzer that can automatically summarize textual data and discover communication networks from publicly accessible social media posts.
# - Netlytic has been in use for over a decade by researchers, educators and students from around the world. It uses APIs to collect publicly accessible posts from Twitter, YouTube and RSS feeds. Netlytic can also support the upload and analysis of users' existing datasets via CSV or Google Sheet.
# - Netlytic's Free Tiers 1 & 2 are ideal for teaching and learning about social media analytics, content analysis and social network analysis (SNA).
#
# You can focus on different social media platform, but we will use this guide (https://docs.google.com/document/u/1/d/1_EH30ycPj2r6t0vH1QSSBjKJ209qq7-nwz2zAJno8Mk/pub?pli=1) to create Twitter user network based on a key hashtag.
#
# 1. Create an online account with Netlytic (https://netlytic.org)
# 2. Connect your Twitter account to Netlytic, following step 1.1 of Part 1 in the guide.
# 3. Click on the "New Dataset", then click on "Twitter" tab.
# 4. Input 9 parameters to collect data to your needs (E.g: you can specify the latitude, longitude, and a diameter of a location; or restrict the number of retweets).
# ![Screen Shot 2022-10-18 at 00.51.14.png](data:image/png;base64,...)
# 5. Click 'Test Quey on Twitter'. If your filters are too restrictive, this may yield no data at all. Modify them such that you actually are able to gain Tweets.
# 6. Click 'Import'. When the screen below pops up, choose "Export as CSV".
# ![Screen Shot 2022-10-18 at 00.55.40.png](data:image/png;base64,...)

# %% [markdown]
# You can proceed to either '3. Text Analysis' or '4. Network Analysis'. Navigate back to the guide on how to filter data to your needs. You can always download the network as a Gephi network by clicking on 'Import'.
# ![Screen Shot 2022-10-18 at 00.57.18.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. BIOLOGICAL NETWORK: STRINGDB
# STRINGDB (https://string-db.org/cgi/input?sessionId=bQIQYcLmR36G&input_page_show_search=on) is a database of known and predicted protein-protein interactions. The interactions include direct (physical) and indirect (functional) associations; they stem from computational prediction, from knowledge transfer between organisms, and from interactions aggregated from other (primary) databases.
#
# To specify your desired starting point of the analysis you have to use the input form at the STRING start page. There are 2 inputs needed: **Protein Name** and **Organisms**.
#
#     Protein by name
#     Protein by sequence
#     Multiple proteins
#     Multiple sequences
#     Organisms
#     Protein families (COGs)
#     Examples
#     Random entry
#
# You can search STRING by single protein name, multiple names or by amino acid sequence (in any format) There are also example inputs and a random input generator which will randomly select a protein with at least 4 predicted links at medium confidence or better. There is a organism entry to see if your species of interest is available. There is the possibility to search by protein family rather than a protein in a single organism, by searching the COGs (clusters of orthologous groups)
#
# Commonly, you enter your protein of interest by supplying its name or identifier. The organism can be selected by clicking on the arrow or directly typing the name inside the relative input field (an autocompletion mechanism will appear to help you). General names that group more than one organism (e.g. "Mammals", "Chordata") can also be used.
#
# ![Screen Shot 2022-10-16 at 01.09.55.png](data:image/png;base64,...)
#
# For instance, to search for protein-protein interactions of KLF4 in Homo Sapiens:
#
# ![Screen Shot 2022-10-16 at 00.57.55.png](data:image/png;base64,...)

# %% [markdown]
# To interpret the network data, refer to this manual (http://version10.string-db.org/help/getting_started/). Pay attention to the **Settings** (where you can further filter data to your needs) and **Analysis** tab (where basic network information is already provided), which would be really helpful for understanding the network itself.
#
# The KLF4 protein-protein interaction network gained is shown below. You can see that a network is already created with basic network metrics provided.
#
# ![Screen Shot 2022-10-16 at 01.23.08.png](data:image/png;base64,...)
#
# We want to download the actual data about each link in this network in a CSV file format. Navigate to the **Exports** tab, and choose **"...as short tabular text output."** We want simple tabular text output - data for the interaction network as tab separated values (TSV format). File can be opened in Excel. This data is also show further down on Table/Export page.
#
#
# ![Screen Shot 2022-10-16 at 01.22.44.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. CITATION NETWORK:
# Here, we will provide you with a database for citation (https://www.aminer.org/ scraping data?

# %% [markdown]
# ## 5. TRANSPORTATION NETWORK:
#
# There are 43 transport networks datasets available on data.world. (https://data.world/datasets/transport-networks). The datasets are available in CSV file formats. You need to create an account for free in order to view these datasets.
